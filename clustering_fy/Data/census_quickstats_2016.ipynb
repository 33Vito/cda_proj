# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
import pickle
import matplotlib.pyplot as pl
import re
import os
from tqdm import tqdm

# %%
# open pickle file
with open('allsource2016.pkl', 'rb') as f:
    source = pickle.load(f)

ssc_map = pd.read_csv('ssc/SSC_2016_AUST.csv')
keep = ['SSC_CODE_2016', 'SSC_NAME_2016', 'STATE_CODE_2016',
        'STATE_NAME_2016']
ssc_map = ssc_map[keep]
ssc_map = ssc_map[ssc_map['STATE_NAME_2016'] == 'New South Wales']
ssc_map = ssc_map.drop_duplicates()
ssc_map.head()
# Out:
#     SSC_CODE_2016       SSC_NAME_2016  STATE_CODE_2016  STATE_NAME_2016
# 0           12402          Lower Boro                1  New South Wales
# 3           13062              Oallen                1  New South Wales
# 8           10547           Braidwood                1  New South Wales
# 42          12452  Majors Creek (NSW)                1  New South Wales
# 49          10070       Araluen (NSW)                1  New South Wales

# %%
quickstats = pd.concat(stats, axis=1).T
# quickstats

# %%
# parse quick summary
stats = []
for i, (suburb, txt) in enumerate(source.items()):
    if i % 100 == 0:
        print('Quickstat Iteration={}'.format(i))
    soup = bs(txt, 'html')
    # find all tables
    tables = soup.find_all('table')
    # parse quick summary
    try:
        stats.append(get_quickstat_2016(tables, suburb))   
    except ValueError as e:
        print(suburb)
        print(e)
# integrate all in one table
quickstats = pd.concat(stats, axis=1).T

# %% [markdown]
# # Parse Quick Stats from 2001 to 2016

# %%
name_to_ssc = ssc_map.set_index('SSC_NAME_2016')['SSC_CODE_2016']

# %%
quickstats.head()
# Out:
#                     People   Male  Female  Median age  Families  \
# Lower Boro           176.0  0.554   0.446        50.0      51.0
# Oallen               141.0  0.555   0.445        50.0      32.0
# Braidwood           1651.0  0.479   0.521        46.0     422.0
# Majors Creek (NSW)   249.0  0.523   0.477        48.0      71.0
# Araluen (NSW)        168.0  0.539   0.461        55.0      38.0
#
#                     Average children per family for families with children  \
# Lower Boro                                                        1.8
# Oallen                                                            1.8
# Braidwood                                                         1.8
# Majors Creek (NSW)                                                1.7
# Araluen (NSW)                                                     1.2
#
#                     Average children per family for all families  \
# Lower Boro                                                   0.5
# Oallen                                                       0.5
# Braidwood                                                    0.6
# Majors Creek (NSW)                                           0.5
# Araluen (NSW)                                                0.2
#
#                     All private dwellings  Average people per household  \
# Lower Boro                          142.0                           2.0
# Oallen                              157.0                           2.0
# Braidwood                           783.0                           2.3
# Majors Creek (NSW)                  132.0                           2.2
# Araluen (NSW)                       112.0                           1.9
#
#                     Median weekly household income  \
# Lower Boro                                  1062.0
# Oallen                                       966.0
# Braidwood                                   1091.0
# Majors Creek (NSW)                          1025.0
# Araluen (NSW)                                716.0
#
#                     Median monthly mortgage repayments  Median weekly rent  \
# Lower Boro                                      1170.0                 0.0
# Oallen                                          1100.0                 0.0
# Braidwood                                       1700.0               278.0
# Majors Creek (NSW)                              1251.0               300.0
# Araluen (NSW)                                    867.0               150.0
#
#                     Average motor vehicles per dwelling
# Lower Boro                                          1.9
# Oallen                                              2.0
# Braidwood                                           1.9
# Majors Creek (NSW)                                  1.9
# Araluen (NSW)                                       1.9

# %%
sscs = [name_to_ssc[x] for x in quickstats.index]
quickstats['SSC_CODE'] = sscs
quickstats.head()
# Out:
#                     People   Male  Female  Median age  Families  \
# Lower Boro           176.0  0.554   0.446        50.0      51.0
# Oallen               141.0  0.555   0.445        50.0      32.0
# Braidwood           1651.0  0.479   0.521        46.0     422.0
# Majors Creek (NSW)   249.0  0.523   0.477        48.0      71.0
# Araluen (NSW)        168.0  0.539   0.461        55.0      38.0
#
#                     Average children per family for families with children  \
# Lower Boro                                                        1.8
# Oallen                                                            1.8
# Braidwood                                                         1.8
# Majors Creek (NSW)                                                1.7
# Araluen (NSW)                                                     1.2
#
#                     Average children per family for all families  \
# Lower Boro                                                   0.5
# Oallen                                                       0.5
# Braidwood                                                    0.6
# Majors Creek (NSW)                                           0.5
# Araluen (NSW)                                                0.2
#
#                     All private dwellings  Average people per household  \
# Lower Boro                          142.0                           2.0
# Oallen                              157.0                           2.0
# Braidwood                           783.0                           2.3
# Majors Creek (NSW)                  132.0                           2.2
# Araluen (NSW)                       112.0                           1.9
#
#                     Median weekly household income  \
# Lower Boro                                  1062.0
# Oallen                                       966.0
# Braidwood                                   1091.0
# Majors Creek (NSW)                          1025.0
# Araluen (NSW)                                716.0
#
#                     Median monthly mortgage repayments  Median weekly rent  \
# Lower Boro                                      1170.0                 0.0
# Oallen                                          1100.0                 0.0
# Braidwood                                       1700.0               278.0
# Majors Creek (NSW)                              1251.0               300.0
# Araluen (NSW)                                    867.0               150.0
#
#                     Average motor vehicles per dwelling  SSC_CODE
# Lower Boro                                          1.9     12402
# Oallen                                              2.0     13062
# Braidwood                                           1.9     10547
# Majors Creek (NSW)                                  1.9     12452
# Araluen (NSW)                                       1.9     10070

# %%
path = 'Quickstat_2016_all.csv'
quickstats.to_csv(path)

# %%
def get_quickstat_2011(tables, suburn):
    """Get quick stats for each suburb at each year."""
    quickstat = {}
    keys = []
    vals = []

    # parse quick summary
    for people in tables[1: 4]:
        for td in people.find_all('td'):
            if len(td.attrs) > 0 and 'class' in td.attrs and td.attrs['class'] == ['summaryData']:
                vals.append(float(td.text.replace(',', '').replace('$', '')))
            else:
                keys.append(td.text)

    quickstat = {k: [v] for k, v in zip(keys, vals)}
    data = pd.DataFrame.from_dict(quickstat).T
    data.columns = [suburb]
    return data

def get_quickstat_2016(tables, suburb):
    """Get quick stats for each suburb at each year."""
    quickstat = {}
    keys = []
    vals = []

    # parse quick summary
    for people in tables[0: 3]:
        for th, td in zip(people.find_all('th'), people.find_all('td')):
            if td.text == '':
                continue  # average children per family
            value = td.text.replace(',', '').replace('$', '')
            if th.text in ['for families with children', 'for all families']:
                k = 'Average children per family ' + th.text
            else:
                k = th.text
            if '%' in value:
                value = float(value.replace('%', '')) * 0.01
            else:
                value = float(value)
            # append values
            keys.append(k)
            vals.append(value)

    quickstat = {k: [v] for k, v in zip(keys, vals)}
    data = pd.DataFrame.from_dict(quickstat).T
    data.columns = [suburb]
    return data

# %% [markdown]
# # Parse Common Table from 2001 to 2016

# %%
# tables[4]

# %% [markdown]
# ### Table mapping

# %%
common_map = {}
uncommon_map = {}
year = '2016'
with open('allsource2016.pkl', 'rb') as f:
    d = pickle.load(f)
soup = bs(d['Ashfield (NSW)'], 'html')
tables = soup.find_all('table')

cmap = {}
ucmap = {}
for i, tb in enumerate(tables):
    try:
        z = re.search(r'(\<\!--).+(-->)', str(tb))
        name = z.group().replace('<!-- ', '').replace('-->', '').strip()
        
    except AttributeError:
        name = tb.text.strip().split('\n')[0]
    try:
        df = parse_common_table(tb, year)
        if len(df.columns) == 0:
            ucmap[i] = name
        else:
            cmap[i] = name
    except:
        cmap[i] = name
# append to overall mapping
common_map[year] = cmap
uncommon_map[year] = ucmap

uncommon_map
# Out:
# {'2016': {9: 'Ancestry, top responses',
#   12: 'Country of birth of father',
#   13: 'Country of birth of mother',
#   14: 'Religious affiliation',
#   15: 'Language, top responses5',
#   18: 'Occupation',
#   19: 'Industry of employment',
#   21: 'Travel to work'}}

# %%
non2016 = [0, 1, 2, 3, 4]
yes2016 = [0, 1, 2, 3]
for year in common_map:
    exclusion = yes2016 if year == '2016' else non2016
    common_map[year] = {k: v for k, v in common_map[year].items() if k not in exclusion and v != ''}

# country of birth should be taken out
for year in common_map:
    c = common_map[year]
    topop = None
    for k, v in c.items():
        if v == 'Country of birth':
            uncommon_map[year][k] = v
            topop = k
    common_map[year].pop(k)
uncommon_map
# Out:
# {'2016': {9: 'Ancestry, top responses',
#   12: 'Country of birth of father',
#   13: 'Country of birth of mother',
#   14: 'Religious affiliation',
#   15: 'Language, top responses5',
#   18: 'Occupation',
#   19: 'Industry of employment',
#   21: 'Travel to work',
#   10: 'Country of birth'}}

# %% [markdown]
# It is consistent that we need to parse table 4 to table 39 for all 4 years.
#
# ### Parse common tables

# %%
commontables = {}

errortables = None
dataroot = 'census_data'
if not os.path.exists(dataroot):
    os.mkdir(dataroot)
    
year = '2016'
# open pickle file
with open('allsource2016.pkl', 'rb') as f:
    source = pickle.load(f)

# iterate all common tables
for index, tablename in common_map[year].items():
    name = '{}_{}.csv'.format(year, tablename).replace(' ', '_')
    name = name.replace('/', '_')
    path = os.path.join(dataroot, name)
    print('Year={} Table={}'.format(year, tablename))
#     if os.path.exists(path):
#         continue
    group = []
    for i, (suburb, txt) in enumerate(source.items()):
        if i % 100 == 0:
            print('    Iteration i={}'.format(i))
        soup = bs(txt, 'html')
        # find all tables
        tables = soup.find_all('table')
        try:
            sdata = parse_common_table(tables[index], year)
            group.append(sdata)
        except IndexError:
#             print('  Error with {}, index={}'.format(suburb, index))
            errortables = tables
            continue

    df = pd.concat(group, axis=0).drop_duplicates()
    sscs = [name_to_ssc.get(x, '') for x in df.index]
    df['SSC_CODE'] = sscs
    print('Saving to', path)
    df.to_csv(path)
# Out:
# Year=2016 Table=Age
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
#     Iteration i=800
#     Iteration i=900
#     Iteration i=1000
#     Iteration i=1100
#     Iteration i=1200
#     Iteration i=1300
#     Iteration i=1400
#     Iteration i=1500
#     Iteration i=1600
#     Iteration i=1700
#     Iteration i=1800
#     Iteration i=1900
#     Iteration i=2000
#     Iteration i=2100
#     Iteration i=2200
#     Iteration i=2300
#     Iteration i=2400
#     Iteration i=2500
#     Iteration i=2600
#     Iteration i=2700
#     Iteration i=2800
#     Iteration i=2900
#     Iteration i=3000
#     Iteration i=3100
#     Iteration i=3200
#     Iteration i=3300
#     Iteration i=3400
#     Iteration i=3500
#     Iteration i=3600
#     Iteration i=3700
#     Iteration i=3800
#     Iteration i=3900
#     Iteration i=4000
#     Iteration i=4100
#     Iteration i=4200
#     Iteration i=4300
#     Iteration i=4400
#     Iteration i=4500
# Saving to census_data/2016_Age.csv
# Year=2016 Table=Registered marital status
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
#     Iteration i=800
#     Iteration i=900
#     Iteration i=1000
#     Iteration i=1100
#     Iteration i=1200
#     Iteration i=1300
#     Iteration i=1400
#     Iteration i=1500
#     Iteration i=1600
#     Iteration i=1700
#     Iteration i=1800
#     Iteration i=1900
#     Iteration i=2000
#     Iteration i=2100
#     Iteration i=2200
#     Iteration i=2300
#     Iteration i=2400
#     Iteration i=2500
#     Iteration i=2600
#     Iteration i=2700
#     Iteration i=2800
#     Iteration i=2900
#     Iteration i=3000
#     Iteration i=3100
#     Iteration i=3200
#     Iteration i=3300
#     Iteration i=3400
#     Iteration i=3500
#     Iteration i=3600
#     Iteration i=3700
#     Iteration i=3800
#     Iteration i=3900
#     Iteration i=4000
#     Iteration i=4100
#     Iteration i=4200
#     Iteration i=4300
#     Iteration i=4400
#     Iteration i=4500
# Saving to census_data/2016_Registered_marital_status.csv
# Year=2016 Table=Social marital status
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
#     Iteration i=800
#     Iteration i=900
#     Iteration i=1000
#     Iteration i=1100
#     Iteration i=1200
#     Iteration i=1300
#     Iteration i=1400
#     Iteration i=1500
#     Iteration i=1600
#     Iteration i=1700
#     Iteration i=1800
#     Iteration i=1900
#     Iteration i=2000
#     Iteration i=2100
#     Iteration i=2200
#     Iteration i=2300
#     Iteration i=2400
#     Iteration i=2500
#     Iteration i=2600
#     Iteration i=2700
#     Iteration i=2800
#     Iteration i=2900
#     Iteration i=3000
#     Iteration i=3100
#     Iteration i=3200
#     Iteration i=3300
#     Iteration i=3400
#     Iteration i=3500
#     Iteration i=3600
#     Iteration i=3700
#     Iteration i=3800
#     Iteration i=3900
#     Iteration i=4000
#     Iteration i=4100
#     Iteration i=4200
#     Iteration i=4300
#     Iteration i=4400
#     Iteration i=4500
# Saving to census_data/2016_Social_marital_status.csv
# Year=2016 Table=Education
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
#     Iteration i=800
#     Iteration i=900
#     Iteration i=1000
#     Iteration i=1100
#     Iteration i=1200
#     Iteration i=1300
#     Iteration i=1400
#     Iteration i=1500
#     Iteration i=1600
#     Iteration i=1700
#     Iteration i=1800
#     Iteration i=1900
#     Iteration i=2000
#     Iteration i=2100
#     Iteration i=2200
#     Iteration i=2300
#     Iteration i=2400
#     Iteration i=2500
#     Iteration i=2600
#     Iteration i=2700
#     Iteration i=2800
#     Iteration i=2900
#     Iteration i=3000
#     Iteration i=3100
#     Iteration i=3200
#     Iteration i=3300
#     Iteration i=3400
#     Iteration i=3500
#     Iteration i=3600
#     Iteration i=3700
#     Iteration i=3800
#     Iteration i=3900
#     Iteration i=4000
#     Iteration i=4100
#     Iteration i=4200
#     Iteration i=4300
#     Iteration i=4400
#     Iteration i=4500
# Saving to census_data/2016_Education.csv
# Year=2016 Table=Level of highest Educational attainment
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
#     Iteration i=800
#     Iteration i=900
#     Iteration i=1000
#     Iteration i=1100
#     Iteration i=1200
#     Iteration i=1300
#     Iteration i=1400
#     Iteration i=1500
#     Iteration i=1600
#     Iteration i=1700
#     Iteration i=1800
#     Iteration i=1900
#     Iteration i=2000
#     Iteration i=2100
#     Iteration i=2200
#     Iteration i=2300
#     Iteration i=2400
#     Iteration i=2500
#     Iteration i=2600
#     Iteration i=2700
#     Iteration i=2800
#     Iteration i=2900
#     Iteration i=3000
#     Iteration i=3100
#     Iteration i=3200
#     Iteration i=3300
#     Iteration i=3400
#     Iteration i=3500
#     Iteration i=3600
#     Iteration i=3700
#     Iteration i=3800
#     Iteration i=3900
#     Iteration i=4000
#     Iteration i=4100
#     Iteration i=4200
#     Iteration i=4300
#     Iteration i=4400
#     Iteration i=4500
# Saving to census_data/2016_Level_of_highest_Educational_attainment.csv
# Year=2016 Table=Country of birth
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
#     Iteration i=800
#     Iteration i=900
#     Iteration i=1000
#     Iteration i=1100
#     Iteration i=1200
#     Iteration i=1300
#     Iteration i=1400
#     Iteration i=1500
#     Iteration i=1600
#     Iteration i=1700
#     Iteration i=1800
#     Iteration i=1900
#     Iteration i=2000
#     Iteration i=2100
#     Iteration i=2200
#     Iteration i=2300
#     Iteration i=2400
#     Iteration i=2500
#     Iteration i=2600
#     Iteration i=2700
#     Iteration i=2800
#     Iteration i=2900
#     Iteration i=3000
#     Iteration i=3100
#     Iteration i=3200
#     Iteration i=3300
#     Iteration i=3400
#     Iteration i=3500
#     Iteration i=3600
#     Iteration i=3700
#     Iteration i=3800
#     Iteration i=3900
#     Iteration i=4000
#     Iteration i=4100
#     Iteration i=4200
#     Iteration i=4300
#     Iteration i=4400
#     Iteration i=4500
# Saving to census_data/2016_Country_of_birth.csv
# Year=2016 Table=Country of birth of father and/or mother
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
#     Iteration i=800
#     Iteration i=900
#     Iteration i=1000
#     Iteration i=1100
#     Iteration i=1200
#     Iteration i=1300
#     Iteration i=1400
#     Iteration i=1500
#     Iteration i=1600
#     Iteration i=1700
#     Iteration i=1800
#     Iteration i=1900
#     Iteration i=2000
#     Iteration i=2100
#     Iteration i=2200
#     Iteration i=2300
#     Iteration i=2400
#     Iteration i=2500
#     Iteration i=2600
#     Iteration i=2700
#     Iteration i=2800
#     Iteration i=2900
#     Iteration i=3000
#     Iteration i=3100
#     Iteration i=3200
#     Iteration i=3300
#     Iteration i=3400
#     Iteration i=3500
#     Iteration i=3600
#     Iteration i=3700
#     Iteration i=3800
#     Iteration i=3900
#     Iteration i=4000
#     Iteration i=4100
#     Iteration i=4200
#     Iteration i=4300
#     Iteration i=4400
#     Iteration i=4500
# Saving to census_data/2016_Country_of_birth_of_father_and_or_mother.csv
# Year=2016 Table=Employment
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
#     Iteration i=800
#     Iteration i=900
#     Iteration i=1000
#     Iteration i=1100
#     Iteration i=1200
#     Iteration i=1300
#     Iteration i=1400
#     Iteration i=1500
#     Iteration i=1600
#     Iteration i=1700
#     Iteration i=1800
#     Iteration i=1900
#     Iteration i=2000
#     Iteration i=2100
#     Iteration i=2200
#     Iteration i=2300
#     Iteration i=2400
#     Iteration i=2500
#     Iteration i=2600
#     Iteration i=2700
#     Iteration i=2800
#     Iteration i=2900
#     Iteration i=3000
#     Iteration i=3100
#     Iteration i=3200
#     Iteration i=3300
#     Iteration i=3400
#     Iteration i=3500
#     Iteration i=3600
#     Iteration i=3700
#     Iteration i=3800
#     Iteration i=3900
#     Iteration i=4000
#     Iteration i=4100
#     Iteration i=4200
#     Iteration i=4300
#     Iteration i=4400
#     Iteration i=4500
# Saving to census_data/2016_Employment.csv
# Year=2016 Table=Employment - hours worked
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
#     Iteration i=800
#     Iteration i=900
#     Iteration i=1000
#     Iteration i=1100
#     Iteration i=1200
#     Iteration i=1300
#     Iteration i=1400
#     Iteration i=1500
#     Iteration i=1600
#     Iteration i=1700
#     Iteration i=1800
#     Iteration i=1900
#     Iteration i=2000
#     Iteration i=2100
#     Iteration i=2200
#     Iteration i=2300
#     Iteration i=2400
#     Iteration i=2500
#     Iteration i=2600
#     Iteration i=2700
#     Iteration i=2800
#     Iteration i=2900
#     Iteration i=3000
#     Iteration i=3100
#     Iteration i=3200
#     Iteration i=3300
#     Iteration i=3400
#     Iteration i=3500
#     Iteration i=3600
#     Iteration i=3700
#     Iteration i=3800
#     Iteration i=3900
#     Iteration i=4000
#     Iteration i=4100
#     Iteration i=4200
#     Iteration i=4300
#     Iteration i=4400
#     Iteration i=4500
# Saving to census_data/2016_Employment_-_hours_worked.csv
# Year=2016 Table=Median weekly incomes
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
#     Iteration i=800
#     Iteration i=900
#     Iteration i=1000
#     Iteration i=1100
#     Iteration i=1200
#     Iteration i=1300
#     Iteration i=1400
#     Iteration i=1500
#     Iteration i=1600
#     Iteration i=1700
#     Iteration i=1800
#     Iteration i=1900
#     Iteration i=2000
#     Iteration i=2100
#     Iteration i=2200
#     Iteration i=2300
#     Iteration i=2400
#     Iteration i=2500
#     Iteration i=2600
#     Iteration i=2700
#     Iteration i=2800
#     Iteration i=2900
#     Iteration i=3000
#     Iteration i=3100
#     Iteration i=3200
#     Iteration i=3300
#     Iteration i=3400
#     Iteration i=3500
#     Iteration i=3600
#     Iteration i=3700
#     Iteration i=3800
#     Iteration i=3900
#     Iteration i=4000
#     Iteration i=4100
#     Iteration i=4200
#     Iteration i=4300
#     Iteration i=4400
#     Iteration i=4500
# Saving to census_data/2016_Median_weekly_incomes.csv
# Year=2016 Table=Unpaid work
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
#     Iteration i=800
#     Iteration i=900
#     Iteration i=1000
#     Iteration i=1100
#     Iteration i=1200
#     Iteration i=1300
#     Iteration i=1400
#     Iteration i=1500
#     Iteration i=1600
#     Iteration i=1700
#     Iteration i=1800
#     Iteration i=1900
#     Iteration i=2000
#     Iteration i=2100
#     Iteration i=2200
#     Iteration i=2300
#     Iteration i=2400
#     Iteration i=2500
#     Iteration i=2600
#     Iteration i=2700
#     Iteration i=2800
#     Iteration i=2900
#     Iteration i=3000
#     Iteration i=3100
#     Iteration i=3200
#     Iteration i=3300
#     Iteration i=3400
#     Iteration i=3500
#     Iteration i=3600
#     Iteration i=3700
#     Iteration i=3800
#     Iteration i=3900
#     Iteration i=4000
#     Iteration i=4100
#     Iteration i=4200
#     Iteration i=4300
#     Iteration i=4400
#     Iteration i=4500
# Saving to census_data/2016_Unpaid_work.csv
# Year=2016 Table=Unpaid domestic work
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
#     Iteration i=800
#     Iteration i=900
#     Iteration i=1000
#     Iteration i=1100
#     Iteration i=1200
#     Iteration i=1300
#     Iteration i=1400
#     Iteration i=1500
#     Iteration i=1600
#     Iteration i=1700
#     Iteration i=1800
#     Iteration i=1900
#     Iteration i=2000
#     Iteration i=2100
#     Iteration i=2200
#     Iteration i=2300
#     Iteration i=2400
#     Iteration i=2500
#     Iteration i=2600
#     Iteration i=2700
#     Iteration i=2800
#     Iteration i=2900
#     Iteration i=3000
#     Iteration i=3100
#     Iteration i=3200
#     Iteration i=3300
#     Iteration i=3400
#     Iteration i=3500
#     Iteration i=3600
#     Iteration i=3700
#     Iteration i=3800
#     Iteration i=3900
#     Iteration i=4000
#     Iteration i=4100
#     Iteration i=4200
#     Iteration i=4300
#     Iteration i=4400
#     Iteration i=4500
# Saving to census_data/2016_Unpaid_domestic_work.csv
# Year=2016 Table=Family composition
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
#     Iteration i=800
#     Iteration i=900
#     Iteration i=1000
#     Iteration i=1100
#     Iteration i=1200
#     Iteration i=1300
#     Iteration i=1400
#     Iteration i=1500
#     Iteration i=1600
#     Iteration i=1700
#     Iteration i=1800
#     Iteration i=1900
#     Iteration i=2000
#     Iteration i=2100
#     Iteration i=2200
#     Iteration i=2300
#     Iteration i=2400
#     Iteration i=2500
#     Iteration i=2600
#     Iteration i=2700
#     Iteration i=2800
#     Iteration i=2900
#     Iteration i=3000
#     Iteration i=3100
#     Iteration i=3200
#     Iteration i=3300
#     Iteration i=3400
#     Iteration i=3500
#     Iteration i=3600
#     Iteration i=3700
#     Iteration i=3800
#     Iteration i=3900
#     Iteration i=4000
#     Iteration i=4100
#     Iteration i=4200
#     Iteration i=4300
#     Iteration i=4400
#     Iteration i=4500
# Saving to census_data/2016_Family_composition.csv
# Year=2016 Table=Single (or lone) parents
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
#     Iteration i=800
#     Iteration i=900
#     Iteration i=1000
#     Iteration i=1100
#     Iteration i=1200
#     Iteration i=1300
#     Iteration i=1400
#     Iteration i=1500
#     Iteration i=1600
#     Iteration i=1700
#     Iteration i=1800
#     Iteration i=1900
#     Iteration i=2000
#     Iteration i=2100
#     Iteration i=2200
#     Iteration i=2300
#     Iteration i=2400
#     Iteration i=2500
#     Iteration i=2600
#     Iteration i=2700
#     Iteration i=2800
#     Iteration i=2900
#     Iteration i=3000
#     Iteration i=3100
#     Iteration i=3200
#     Iteration i=3300
#     Iteration i=3400
#     Iteration i=3500
#     Iteration i=3600
#     Iteration i=3700
#     Iteration i=3800
#     Iteration i=3900
#     Iteration i=4000
#     Iteration i=4100
#     Iteration i=4200
#     Iteration i=4300
#     Iteration i=4400
#     Iteration i=4500
# Saving to census_data/2016_Single_(or_lone)_parents.csv
# Year=2016 Table=Employment status of parents in couple families
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
#     Iteration i=800
#     Iteration i=900
#     Iteration i=1000
#     Iteration i=1100
#     Iteration i=1200
#     Iteration i=1300
#     Iteration i=1400
#     Iteration i=1500
#     Iteration i=1600
#     Iteration i=1700
#     Iteration i=1800
#     Iteration i=1900
#     Iteration i=2000
#     Iteration i=2100
#     Iteration i=2200
#     Iteration i=2300
#     Iteration i=2400
#     Iteration i=2500
#     Iteration i=2600
#     Iteration i=2700
#     Iteration i=2800
#     Iteration i=2900
#     Iteration i=3000
#     Iteration i=3100
#     Iteration i=3200
#     Iteration i=3300
#     Iteration i=3400
#     Iteration i=3500
#     Iteration i=3600
#     Iteration i=3700
#     Iteration i=3800
#     Iteration i=3900
#     Iteration i=4000
#     Iteration i=4100
#     Iteration i=4200
#     Iteration i=4300
#     Iteration i=4400
#     Iteration i=4500
# Saving to census_data/2016_Employment_status_of_parents_in_couple_families.csv
# Year=2016 Table=Dwelling type
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
#     Iteration i=800
#     Iteration i=900
#     Iteration i=1000
#     Iteration i=1100
#     Iteration i=1200
#     Iteration i=1300
#     Iteration i=1400
#     Iteration i=1500
#     Iteration i=1600
#     Iteration i=1700
#     Iteration i=1800
#     Iteration i=1900
#     Iteration i=2000
#     Iteration i=2100
#     Iteration i=2200
#     Iteration i=2300
#     Iteration i=2400
#     Iteration i=2500
#     Iteration i=2600
#     Iteration i=2700
#     Iteration i=2800
#     Iteration i=2900
#     Iteration i=3000
#     Iteration i=3100
#     Iteration i=3200
#     Iteration i=3300
#     Iteration i=3400
#     Iteration i=3500
#     Iteration i=3600
#     Iteration i=3700
#     Iteration i=3800
#     Iteration i=3900
#     Iteration i=4000
#     Iteration i=4100
#     Iteration i=4200
#     Iteration i=4300
#     Iteration i=4400
#     Iteration i=4500
# Saving to census_data/2016_Dwelling_type.csv
# Year=2016 Table=Occupied private dwellings
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
#     Iteration i=800
#     Iteration i=900
#     Iteration i=1000
#     Iteration i=1100
#     Iteration i=1200
#     Iteration i=1300
#     Iteration i=1400
#     Iteration i=1500
#     Iteration i=1600
#     Iteration i=1700
#     Iteration i=1800
#     Iteration i=1900
#     Iteration i=2000
#     Iteration i=2100
#     Iteration i=2200
#     Iteration i=2300
#     Iteration i=2400
#     Iteration i=2500
#     Iteration i=2600
#     Iteration i=2700
#     Iteration i=2800
#     Iteration i=2900
#     Iteration i=3000
#     Iteration i=3100
#     Iteration i=3200
#     Iteration i=3300
#     Iteration i=3400
#     Iteration i=3500
#     Iteration i=3600
#     Iteration i=3700
#     Iteration i=3800
#     Iteration i=3900
#     Iteration i=4000
#     Iteration i=4100
#     Iteration i=4200
#     Iteration i=4300
#     Iteration i=4400
#     Iteration i=4500
# Saving to census_data/2016_Occupied_private_dwellings.csv
# Year=2016 Table=Number of bedrooms
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
#     Iteration i=800
#     Iteration i=900
#     Iteration i=1000
#     Iteration i=1100
#     Iteration i=1200
#     Iteration i=1300
#     Iteration i=1400
#     Iteration i=1500
#     Iteration i=1600
#     Iteration i=1700
#     Iteration i=1800
#     Iteration i=1900
#     Iteration i=2000
#     Iteration i=2100
#     Iteration i=2200
#     Iteration i=2300
#     Iteration i=2400
#     Iteration i=2500
#     Iteration i=2600
#     Iteration i=2700
#     Iteration i=2800
#     Iteration i=2900
#     Iteration i=3000
#     Iteration i=3100
#     Iteration i=3200
#     Iteration i=3300
#     Iteration i=3400
#     Iteration i=3500
#     Iteration i=3600
#     Iteration i=3700
#     Iteration i=3800
#     Iteration i=3900
#     Iteration i=4000
#     Iteration i=4100
#     Iteration i=4200
#     Iteration i=4300
#     Iteration i=4400
#     Iteration i=4500
# Saving to census_data/2016_Number_of_bedrooms.csv
# Year=2016 Table=Tenure
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
#     Iteration i=800
#     Iteration i=900
#     Iteration i=1000
#     Iteration i=1100
#     Iteration i=1200
#     Iteration i=1300
#     Iteration i=1400
#     Iteration i=1500
#     Iteration i=1600
#     Iteration i=1700
#     Iteration i=1800
#     Iteration i=1900
#     Iteration i=2000
#     Iteration i=2100
#     Iteration i=2200
#     Iteration i=2300
#     Iteration i=2400
#     Iteration i=2500
#     Iteration i=2600
#     Iteration i=2700
#     Iteration i=2800
#     Iteration i=2900
#     Iteration i=3000
#     Iteration i=3100
#     Iteration i=3200
#     Iteration i=3300
#     Iteration i=3400
#     Iteration i=3500
#     Iteration i=3600
#     Iteration i=3700
#     Iteration i=3800
#     Iteration i=3900
#     Iteration i=4000
#     Iteration i=4100
#     Iteration i=4200
#     Iteration i=4300
#     Iteration i=4400
#     Iteration i=4500
# Saving to census_data/2016_Tenure.csv
# Year=2016 Table=Household composition
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
#     Iteration i=800
#     Iteration i=900
#     Iteration i=1000
#     Iteration i=1100
#     Iteration i=1200
#     Iteration i=1300
#     Iteration i=1400
#     Iteration i=1500
#     Iteration i=1600
#     Iteration i=1700
#     Iteration i=1800
#     Iteration i=1900
#     Iteration i=2000
#     Iteration i=2100
#     Iteration i=2200
#     Iteration i=2300
#     Iteration i=2400
#     Iteration i=2500
#     Iteration i=2600
#     Iteration i=2700
#     Iteration i=2800
#     Iteration i=2900
#     Iteration i=3000
#     Iteration i=3100
#     Iteration i=3200
#     Iteration i=3300
#     Iteration i=3400
#     Iteration i=3500
#     Iteration i=3600
#     Iteration i=3700
#     Iteration i=3800
#     Iteration i=3900
#     Iteration i=4000
#     Iteration i=4100
#     Iteration i=4200
#     Iteration i=4300
#     Iteration i=4400
#     Iteration i=4500
# Saving to census_data/2016_Household_composition.csv
# Year=2016 Table=Household income
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
#     Iteration i=800
#     Iteration i=900
#     Iteration i=1000
#     Iteration i=1100
#     Iteration i=1200
#     Iteration i=1300
#     Iteration i=1400
#     Iteration i=1500
#     Iteration i=1600
#     Iteration i=1700
#     Iteration i=1800
#     Iteration i=1900
#     Iteration i=2000
#     Iteration i=2100
#     Iteration i=2200
#     Iteration i=2300
#     Iteration i=2400
#     Iteration i=2500
#     Iteration i=2600
#     Iteration i=2700
#     Iteration i=2800
#     Iteration i=2900
#     Iteration i=3000
#     Iteration i=3100
#     Iteration i=3200
#     Iteration i=3300
#     Iteration i=3400
#     Iteration i=3500
#     Iteration i=3600
#     Iteration i=3700
#     Iteration i=3800
#     Iteration i=3900
#     Iteration i=4000
#     Iteration i=4100
#     Iteration i=4200
#     Iteration i=4300
#     Iteration i=4400
#     Iteration i=4500
# Saving to census_data/2016_Household_income.csv
# Year=2016 Table=Rent weekly payments
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
#     Iteration i=800
#     Iteration i=900
#     Iteration i=1000
#     Iteration i=1100
#     Iteration i=1200
#     Iteration i=1300
#     Iteration i=1400
#     Iteration i=1500
#     Iteration i=1600
#     Iteration i=1700
#     Iteration i=1800
#     Iteration i=1900
#     Iteration i=2000
#     Iteration i=2100
#     Iteration i=2200
#     Iteration i=2300
#     Iteration i=2400
#     Iteration i=2500
#     Iteration i=2600
#     Iteration i=2700
#     Iteration i=2800
#     Iteration i=2900
#     Iteration i=3000
#     Iteration i=3100
#     Iteration i=3200
#     Iteration i=3300
#     Iteration i=3400
#     Iteration i=3500
#     Iteration i=3600
#     Iteration i=3700
#     Iteration i=3800
#     Iteration i=3900
#     Iteration i=4000
#     Iteration i=4100
#     Iteration i=4200
#     Iteration i=4300
#     Iteration i=4400
#     Iteration i=4500
# Saving to census_data/2016_Rent_weekly_payments.csv
# Year=2016 Table=Mortgage monthly repayments
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
#     Iteration i=800
#     Iteration i=900
#     Iteration i=1000
#     Iteration i=1100
#     Iteration i=1200
#     Iteration i=1300
#     Iteration i=1400
#     Iteration i=1500
#     Iteration i=1600
#     Iteration i=1700
#     Iteration i=1800
#     Iteration i=1900
#     Iteration i=2000
#     Iteration i=2100
#     Iteration i=2200
#     Iteration i=2300
#     Iteration i=2400
#     Iteration i=2500
#     Iteration i=2600
#     Iteration i=2700
#     Iteration i=2800
#     Iteration i=2900
#     Iteration i=3000
#     Iteration i=3100
#     Iteration i=3200
#     Iteration i=3300
#     Iteration i=3400
#     Iteration i=3500
#     Iteration i=3600
#     Iteration i=3700
#     Iteration i=3800
#     Iteration i=3900
#     Iteration i=4000
#     Iteration i=4100
#     Iteration i=4200
#     Iteration i=4300
#     Iteration i=4400
#     Iteration i=4500
# Saving to census_data/2016_Mortgage_monthly_repayments.csv
# Year=2016 Table=Number of registered motor vehicles
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
#     Iteration i=800
#     Iteration i=900
#     Iteration i=1000
#     Iteration i=1100
#     Iteration i=1200
#     Iteration i=1300
#     Iteration i=1400
#     Iteration i=1500
#     Iteration i=1600
#     Iteration i=1700
#     Iteration i=1800
#     Iteration i=1900
#     Iteration i=2000
#     Iteration i=2100
#     Iteration i=2200
#     Iteration i=2300
#     Iteration i=2400
#     Iteration i=2500
#     Iteration i=2600
#     Iteration i=2700
#     Iteration i=2800
#     Iteration i=2900
#     Iteration i=3000
#     Iteration i=3100
#     Iteration i=3200
#     Iteration i=3300
#     Iteration i=3400
#     Iteration i=3500
#     Iteration i=3600
#     Iteration i=3700
#     Iteration i=3800
#     Iteration i=3900
#     Iteration i=4000
#     Iteration i=4100
#     Iteration i=4200
#     Iteration i=4300
#     Iteration i=4400
#     Iteration i=4500
# Saving to census_data/2016_Number_of_registered_motor_vehicles.csv
# Year=2016 Table=Dwelling internet connection
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
#     Iteration i=800
#     Iteration i=900
#     Iteration i=1000
#     Iteration i=1100
#     Iteration i=1200
#     Iteration i=1300
#     Iteration i=1400
#     Iteration i=1500
#     Iteration i=1600
#     Iteration i=1700
#     Iteration i=1800
#     Iteration i=1900
#     Iteration i=2000
#     Iteration i=2100
#     Iteration i=2200
#     Iteration i=2300
#     Iteration i=2400
#     Iteration i=2500
#     Iteration i=2600
#     Iteration i=2700
#     Iteration i=2800
#     Iteration i=2900
#     Iteration i=3000
#     Iteration i=3100
#     Iteration i=3200
#     Iteration i=3300
#     Iteration i=3400
#     Iteration i=3500
#     Iteration i=3600
#     Iteration i=3700
#     Iteration i=3800
#     Iteration i=3900
#     Iteration i=4000
#     Iteration i=4100
#     Iteration i=4200
#     Iteration i=4300
#     Iteration i=4400
#     Iteration i=4500
# Saving to census_data/2016_Dwelling_internet_connection.csv
# Year=2016 Table=People characteristics
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
#     Iteration i=800
#     Iteration i=900
#     Iteration i=1000
#     Iteration i=1100
#     Iteration i=1200
#     Iteration i=1300
#     Iteration i=1400
#     Iteration i=1500
#     Iteration i=1600
#     Iteration i=1700
#     Iteration i=1800
#     Iteration i=1900
#     Iteration i=2000
#     Iteration i=2100
#     Iteration i=2200
#     Iteration i=2300
#     Iteration i=2400
#     Iteration i=2500
#     Iteration i=2600
#     Iteration i=2700
#     Iteration i=2800
#     Iteration i=2900
#     Iteration i=3000
#     Iteration i=3100
#     Iteration i=3200
#     Iteration i=3300
#     Iteration i=3400
#     Iteration i=3500
#     Iteration i=3600
#     Iteration i=3700
#     Iteration i=3800
#     Iteration i=3900
#     Iteration i=4000
#     Iteration i=4100
#     Iteration i=4200
#     Iteration i=4300
#     Iteration i=4400
#     Iteration i=4500
# Saving to census_data/2016_People_characteristics.csv
# Year=2016 Table=Dwelling characteristics
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
#     Iteration i=800
#     Iteration i=900
#     Iteration i=1000
#     Iteration i=1100
#     Iteration i=1200
#     Iteration i=1300
#     Iteration i=1400
#     Iteration i=1500
#     Iteration i=1600
#     Iteration i=1700
#     Iteration i=1800
#     Iteration i=1900
#     Iteration i=2000
#     Iteration i=2100
#     Iteration i=2200
#     Iteration i=2300
#     Iteration i=2400
#     Iteration i=2500
#     Iteration i=2600
#     Iteration i=2700
#     Iteration i=2800
#     Iteration i=2900
#     Iteration i=3000
#     Iteration i=3100
#     Iteration i=3200
#     Iteration i=3300
#     Iteration i=3400
#     Iteration i=3500
#     Iteration i=3600
#     Iteration i=3700
#     Iteration i=3800
#     Iteration i=3900
#     Iteration i=4000
#     Iteration i=4100
#     Iteration i=4200
#     Iteration i=4300
#     Iteration i=4400
#     Iteration i=4500
# Saving to census_data/2016_Dwelling_characteristics.csv

# %%
sscs = [name_to_ssc.get(x, '') for x in df.index]
df['SSC_CODE'] = sscs
print('Saving to', path)
df.to_csv(path)
# Out:
# Saving to census_data/2016_Age.csv

# %%
df
# Out:
# Age                                        Median age    0-4 years  \
# Lower Boro                                         50            9
# New South Wales                                    38       465135
# Australia                                          38  1.46478e+06
# Oallen                                             50            4
# Braidwood                                          46          103
# Majors Creek (NSW)                                 48           18
# Araluen (NSW)                                      55            3
# Reidsdale                                          49            7
# Bombay                                             44            8
# Warri                                              41            7
# Manar                                              43            0
# Mongarlowe                                         55            0
# Karabar                                            37          518
# Queanbeyan                                         37          435
# Crestwood                                          36          317
# Queanbeyan East                                    33          339
# Greenleigh                                         48           12
# The Ridgeway                                       51            3
# Bungendore                                         38          325
# Sutton (NSW)                                       44           76
# Carwoola                                           45           49
# Hoskinstown                                        42            9
# Captains Flat                                      38           50
# Burra (Queanbeyan-Palerang Regional - NSW)         46           37
# Mount Fairy                                        47           11
# Mulloon                                            46            0
# Royalla                                            41           40
# Primrose Valley                                    40            4
# Urila                                              43            4
# Tarago                                             44           30
# ...                                               ...          ...
# Caringbah South                                    42          773
# Dolans Bay                                         43           23
# Kurnell                                            37          173
# Greenhills Beach                                   34           77
# Cronulla                                           39          873
# Bundeena                                           48          114
# Maianbar                                           46           18
# Woolooware                                         39          245
# Lilli Pilli (Sutherland Shire - NSW)               42           72
# Port Hacking                                       42           55
# Burraneer                                          43          168
# Heathcote (NSW)                                    42          364
# Waterfall                                          39           32
# Illawong                                           43          355
# Alfords Point                                      40          143
# Barden Ridge                                       37          196
# Menai                                              38          634
# Bangor (NSW)                                       42          346
# Woronora                                           42          115
# Bonnet Bay                                         43          124
# Jannali                                            39          422
# Oyster Bay                                         39          396
# Como (NSW)                                         39          305
# Kareela                                            42          219
# Kirrawee                                           40          638
# Sutherland (NSW)                                   36          787
# Loftus                                             40          278
# Engadine                                           38         1272
# Yarrawarrah                                        40          170
# Woronora Heights                                   40          123
#
# Age                                           5-9 years  10-14 years  \
# Lower Boro                                            5           10
# New South Wales                                  478184       443009
# Australia                                   1.50265e+06  1.39718e+06
# Oallen                                                3           11
# Braidwood                                           116           96
# Majors Creek (NSW)                                   22           14
# Araluen (NSW)                                         0            7
# Reidsdale                                             3           10
# Bombay                                               15           10
# Warri                                                12            3
# Manar                                                 6           12
# Mongarlowe                                            3            8
# Karabar                                             564          542
# Queanbeyan                                          259          204
# Crestwood                                           260          196
# Queanbeyan East                                     204          136
# Greenleigh                                           37           49
# The Ridgeway                                          8           10
# Bungendore                                          343          320
# Sutton (NSW)                                         89          123
# Carwoola                                             92           97
# Hoskinstown                                           9           14
# Captains Flat                                        42           37
# Burra (Queanbeyan-Palerang Regional - NSW)           45           55
# Mount Fairy                                          14           19
# Mulloon                                              12            8
# Royalla                                              89           95
# Primrose Valley                                       9           11
# Urila                                                12            9
# Tarago                                               33           20
# ...                                                 ...          ...
# Caringbah South                                     892          838
# Dolans Bay                                           30           50
# Kurnell                                             192          211
# Greenhills Beach                                     59           73
# Cronulla                                            707          653
# Bundeena                                            108          113
# Maianbar                                             32           36
# Woolooware                                          280          264
# Lilli Pilli (Sutherland Shire - NSW)                 90          123
# Port Hacking                                         84           87
# Burraneer                                           250          283
# Heathcote (NSW)                                     423          370
# Waterfall                                            39           40
# Illawong                                            378          461
# Alfords Point                                       184          192
# Barden Ridge                                        279          360
# Menai                                               700          746
# Bangor (NSW)                                        346          323
# Woronora                                            146          154
# Bonnet Bay                                          157          142
# Jannali                                             519          375
# Oyster Bay                                          490          424
# Como (NSW)                                          343          321
# Kareela                                             264          233
# Kirrawee                                            611          559
# Sutherland (NSW)                                    542          446
# Loftus                                              322          327
# Engadine                                           1507         1293
# Yarrawarrah                                         207          171
# Woronora Heights                                    162          226
#
# Age                                        15-19 years  20-24 years  \
# Lower Boro                                           9            7
# New South Wales                                 448425       489673
# Australia                                   1.4216e+06  1.56679e+06
# Oallen                                               6            4
# Braidwood                                           83           59
# Majors Creek (NSW)                                  10            8
# Araluen (NSW)                                        7            7
# Reidsdale                                            5            0
# Bombay                                               5            0
# Warri                                                4            0
# Manar                                               14            0
# Mongarlowe                                           7            3
# Karabar                                            582          534
# Queanbeyan                                         255          434
# Crestwood                                          177          325
# Queanbeyan East                                    159          299
# Greenleigh                                          60           50
# The Ridgeway                                         9           12
# Bungendore                                         288          173
# Sutton (NSW)                                       130           99
# Carwoola                                            93           78
# Hoskinstown                                          9           11
# Captains Flat                                       26           30
# Burra (Queanbeyan-Palerang Regional - NSW)          63           37
# Mount Fairy                                         12            7
# Mulloon                                             13            6
# Royalla                                             84           57
# Primrose Valley                                      5            6
# Urila                                                9           10
# Tarago                                              15           10
# ...                                                ...          ...
# Caringbah South                                    839          711
# Dolans Bay                                          59           40
# Kurnell                                            123           98
# Greenhills Beach                                    79           52
# Cronulla                                           690         1115
# Bundeena                                            98           94
# Maianbar                                            23           18
# Woolooware                                         271          226
# Lilli Pilli (Sutherland Shire - NSW)               104           96
# Port Hacking                                        91           64
# Burraneer                                          278          228
# Heathcote (NSW)                                    371          354
# Waterfall                                           33           20
# Illawong                                           491          551
# Alfords Point                                      239          279
# Barden Ridge                                       425          421
# Menai                                              832          763
# Bangor (NSW)                                       354          334
# Woronora                                           167          138
# Bonnet Bay                                         146          124
# Jannali                                            332          339
# Oyster Bay                                         340          273
# Como (NSW)                                         249          209
# Kareela                                            204          159
# Kirrawee                                           497          467
# Sutherland (NSW)                                   454          576
# Loftus                                             256          213
# Engadine                                          1028          819
# Yarrawarrah                                        153          188
# Woronora Heights                                   279          266
#
# Age                                        25-29 years  30-34 years  \
# Lower Boro                                           4            6
# New South Wales                                 527161       540360
# Australia                                   1.6646e+06  1.70385e+06
# Oallen                                               8            3
# Braidwood                                           71           86
# Majors Creek (NSW)                                   3           11
# Araluen (NSW)                                        0            5
# Reidsdale                                            4           18
# Bombay                                               0            3
# Warri                                                4            6
# Manar                                                5            5
# Mongarlowe                                           0            3
# Karabar                                            536          550
# Queanbeyan                                         689          616
# Crestwood                                          457          479
# Queanbeyan East                                    450          464
# Greenleigh                                          23           14
# The Ridgeway                                         6            9
# Bungendore                                         203          265
# Sutton (NSW)                                        62           67
# Carwoola                                            56           59
# Hoskinstown                                         10           18
# Captains Flat                                       27           59
# Burra (Queanbeyan-Palerang Regional - NSW)          28           26
# Mount Fairy                                          4            5
# Mulloon                                              5            6
# Royalla                                             37           21
# Primrose Valley                                      3           11
# Urila                                                7            0
# Tarago                                              18           34
# ...                                                ...          ...
# Caringbah South                                    491          539
# Dolans Bay                                          33           22
# Kurnell                                            105          146
# Greenhills Beach                                    32           37
# Cronulla                                          1926         1788
# Bundeena                                            55           83
# Maianbar                                            21           29
# Woolooware                                         243          233
# Lilli Pilli (Sutherland Shire - NSW)                53           38
# Port Hacking                                        38           41
# Burraneer                                          151          120
# Heathcote (NSW)                                    292          284
# Waterfall                                           21           23
# Illawong                                           453          336
# Alfords Point                                      221          117
# Barden Ridge                                       213          170
# Menai                                              577          533
# Bangor (NSW)                                       280          338
# Woronora                                            78           89
# Bonnet Bay                                          84          103
# Jannali                                            326          410
# Oyster Bay                                         211          286
# Como (NSW)                                         139          194
# Kareela                                            109          167
# Kirrawee                                           511          635
# Sutherland (NSW)                                  1146         1145
# Loftus                                             193          217
# Engadine                                           766         1078
# Yarrawarrah                                        143          152
# Woronora Heights                                   158           82
#
# Age                                         35-39 years  40-44 years  ...  \
# Lower Boro                                            6            5  ...
# New South Wales                                  499724       503169  ...
# Australia                                   1.56168e+06  1.58326e+06  ...
# Oallen                                                7            6  ...
# Braidwood                                            70          111  ...
# Majors Creek (NSW)                                   11           21  ...
# Araluen (NSW)                                         4           11  ...
# Reidsdale                                             4            5  ...
# Bombay                                                6           21  ...
# Warri                                                 9           15  ...
# Manar                                                 4           12  ...
# Mongarlowe                                            7            3  ...
# Karabar                                             532          580  ...
# Queanbeyan                                          442          392  ...
# Crestwood                                           383          338  ...
# Queanbeyan East                                     300          250  ...
# Greenleigh                                           31           45  ...
# The Ridgeway                                          5            8  ...
# Bungendore                                          338          329  ...
# Sutton (NSW)                                         76          119  ...
# Carwoola                                             69           95  ...
# Hoskinstown                                           5            5  ...
# Captains Flat                                        41           53  ...
# Burra (Queanbeyan-Palerang Regional - NSW)           39           49  ...
# Mount Fairy                                           6           11  ...
# Mulloon                                               7            7  ...
# Royalla                                              51           87  ...
# Primrose Valley                                      10           10  ...
# Urila                                                 6           15  ...
# Tarago                                               14           24  ...
# ...                                                 ...          ...  ...
# Caringbah South                                     692          914  ...
# Dolans Bay                                           24           39  ...
# Kurnell                                             158          194  ...
# Greenhills Beach                                     69           57  ...
# Cronulla                                           1317         1146  ...
# Bundeena                                             76          111  ...
# Maianbar                                             22           37  ...
# Woolooware                                          256          272  ...
# Lilli Pilli (Sutherland Shire - NSW)                 60           94  ...
# Port Hacking                                         55           69  ...
# Burraneer                                           158          246  ...
# Heathcote (NSW)                                     345          435  ...
# Waterfall                                            39           42  ...
# Illawong                                            372          408  ...
# Alfords Point                                       158          178  ...
# Barden Ridge                                        207          271  ...
# Menai                                               612          751  ...
# Bangor (NSW)                                        310          316  ...
# Woronora                                            128          187  ...
# Bonnet Bay                                          143          183  ...
# Jannali                                             423          539  ...
# Oyster Bay                                          355          479  ...
# Como (NSW)                                          291          350  ...
# Kareela                                             231          281  ...
# Kirrawee                                            658          678  ...
# Sutherland (NSW)                                    958          804  ...
# Loftus                                              257          352  ...
# Engadine                                           1405         1394  ...
# Yarrawarrah                                         166          193  ...
# Woronora Heights                                    127          198  ...
#
# Age                                        40-44 years (%) 45-49 years (%)  \
# Lower Boro                                             2.9             9.8
# New South Wales                                        6.7             6.6
# Australia                                              6.8             6.8
# Oallen                                                 4.5             6.8
# Braidwood                                              6.7             6.3
# Majors Creek (NSW)                                     8.4             7.6
# Araluen (NSW)                                          6.3            10.3
# Reidsdale                                              3.9             7.8
# Bombay                                                16.8             6.4
# Warri                                                 13.9             7.4
# Manar                                                 10.9            10.9
# Mongarlowe                                             2.4             7.2
# Karabar                                                7.0             7.5
# Queanbeyan                                             6.3             6.2
# Crestwood                                              7.4             6.9
# Queanbeyan East                                        6.4             7.5
# Greenleigh                                             6.6             7.0
# The Ridgeway                                           4.9             4.3
# Bungendore                                             7.9             9.3
# Sutton (NSW)                                           7.2             8.8
# Carwoola                                               6.7             9.3
# Hoskinstown                                            2.7            14.1
# Captains Flat                                          8.8             6.0
# Burra (Queanbeyan-Palerang Regional - NSW)             6.2            10.0
# Mount Fairy                                            5.2             9.5
# Mulloon                                                5.1            10.9
# Royalla                                                8.7            11.9
# Primrose Valley                                        7.1            12.9
# Urila                                                 10.8            13.7
# Tarago                                                 5.9             6.7
# ...                                                    ...             ...
# Caringbah South                                        7.5             6.7
# Dolans Bay                                             6.5             7.1
# Kurnell                                                8.5             7.3
# Greenhills Beach                                       7.2            10.3
# Cronulla                                               6.3             6.0
# Bundeena                                               5.8             8.1
# Maianbar                                               7.4             8.8
# Woolooware                                             6.8             7.2
# Lilli Pilli (Sutherland Shire - NSW)                   6.8             7.1
# Port Hacking                                           6.3             9.4
# Burraneer                                              6.8             8.8
# Heathcote (NSW)                                        7.3             6.8
# Waterfall                                              8.7             8.5
# Illawong                                               5.6             6.5
# Alfords Point                                          5.7             6.1
# Barden Ridge                                           6.3             8.5
# Menai                                                  7.3             7.7
# Bangor (NSW)                                           5.7             6.7
# Woronora                                               8.5             9.1
# Bonnet Bay                                             8.1             7.3
# Jannali                                                8.7             7.5
# Oyster Bay                                             8.7             8.0
# Como (NSW)                                             8.8             8.2
# Kareela                                                8.1             6.4
# Kirrawee                                               7.3             6.3
# Sutherland (NSW)                                       7.4             6.3
# Loftus                                                 8.5             7.7
# Engadine                                               8.0             6.9
# Yarrawarrah                                            7.1             6.3
# Woronora Heights                                       6.9             8.5
#
# Age                                        50-54 years (%) 55-59 years (%)  \
# Lower Boro                                             8.1             8.1
# New South Wales                                        6.5             6.3
# Australia                                              6.5             6.2
# Oallen                                                 6.0            14.3
# Braidwood                                              6.3             7.8
# Majors Creek (NSW)                                     4.8            10.8
# Araluen (NSW)                                         12.0            12.6
# Reidsdale                                              6.2            10.2
# Bombay                                                 5.6             4.8
# Warri                                                  4.6            16.7
# Manar                                                  8.2             9.1
# Mongarlowe                                             8.0            15.2
# Karabar                                                7.0             6.9
# Queanbeyan                                             6.9             5.7
# Crestwood                                              5.6             5.4
# Queanbeyan East                                        6.4             6.3
# Greenleigh                                            11.3             9.1
# The Ridgeway                                           8.6             8.0
# Bungendore                                             7.3             7.0
# Sutton (NSW)                                           9.0             7.3
# Carwoola                                               9.1            10.1
# Hoskinstown                                           10.3             5.9
# Captains Flat                                          9.0             7.3
# Burra (Queanbeyan-Palerang Regional - NSW)             7.5             9.3
# Mount Fairy                                           11.0            12.9
# Mulloon                                               10.9            13.0
# Royalla                                                9.6             7.5
# Primrose Valley                                       10.0            10.7
# Urila                                                  4.3             9.4
# Tarago                                                 9.7             9.2
# ...                                                    ...             ...
# Caringbah South                                        6.6             7.1
# Dolans Bay                                            10.8             9.3
# Kurnell                                                6.6             6.1
# Greenhills Beach                                       9.2             6.3
# Cronulla                                               6.5             7.3
# Bundeena                                               9.2             8.2
# Maianbar                                              12.4             7.6
# Woolooware                                             7.0             6.9
# Lilli Pilli (Sutherland Shire - NSW)                   8.7             8.0
# Port Hacking                                           7.4             6.8
# Burraneer                                              7.8             8.0
# Heathcote (NSW)                                        7.0             5.9
# Waterfall                                              5.6             4.3
# Illawong                                               7.8             9.7
# Alfords Point                                          8.4            11.9
# Barden Ridge                                           9.3             8.5
# Menai                                                  8.1             8.1
# Bangor (NSW)                                           6.7             7.6
# Woronora                                               8.9             6.4
# Bonnet Bay                                             7.0             7.5
# Jannali                                                6.5             6.1
# Oyster Bay                                             6.6             6.1
# Como (NSW)                                             6.9             7.0
# Kareela                                                6.9             5.1
# Kirrawee                                               5.8             5.7
# Sutherland (NSW)                                       6.0             5.4
# Loftus                                                 6.3             5.1
# Engadine                                               5.7             5.2
# Yarrawarrah                                            7.2             6.8
# Woronora Heights                                       8.5            10.6
#
# Age                                        60-64 years (%) 65-69 years (%)  \
# Lower Boro                                             9.8            16.8
# New South Wales                                        5.6             5.1
# Australia                                              5.6             5.1
# Oallen                                                 9.8            15.8
# Braidwood                                              6.9             6.3
# Majors Creek (NSW)                                     7.6             9.2
# Araluen (NSW)                                         10.9             9.1
# Reidsdale                                              5.5            13.3
# Bombay                                                 7.2             7.2
# Warri                                                  5.6             2.8
# Manar                                                  7.3             8.2
# Mongarlowe                                            13.6            15.2
# Karabar                                                5.8             4.7
# Queanbeyan                                             4.9             4.4
# Crestwood                                              4.6             4.6
# Queanbeyan East                                        4.3             2.8
# Greenleigh                                             8.2             7.0
# The Ridgeway                                           8.0             8.6
# Bungendore                                             5.2             4.3
# Sutton (NSW)                                           8.4             7.8
# Carwoola                                               8.9             7.6
# Hoskinstown                                            7.0             3.2
# Captains Flat                                          6.5             6.0
# Burra (Queanbeyan-Palerang Regional - NSW)             7.9             7.5
# Mount Fairy                                           10.0             2.9
# Mulloon                                                8.0             2.2
# Royalla                                                6.5             4.3
# Primrose Valley                                        9.3             3.6
# Urila                                                  7.9            10.8
# Tarago                                                 7.4             8.2
# ...                                                    ...             ...
# Caringbah South                                        6.2             5.8
# Dolans Bay                                             3.2             5.1
# Kurnell                                                5.1             4.9
# Greenhills Beach                                       4.9             0.9
# Cronulla                                               6.6             5.7
# Bundeena                                               7.7             8.6
# Maianbar                                               9.2             6.8
# Woolooware                                             5.8             5.0
# Lilli Pilli (Sutherland Shire - NSW)                   7.7             5.6
# Port Hacking                                           7.4             4.2
# Burraneer                                              6.6             5.4
# Heathcote (NSW)                                        6.2             4.7
# Waterfall                                              7.9             4.3
# Illawong                                               8.7             6.3
# Alfords Point                                          7.9             5.1
# Barden Ridge                                           5.9             3.5
# Menai                                                  5.9             4.2
# Bangor (NSW)                                           8.6             7.2
# Woronora                                               6.6             6.0
# Bonnet Bay                                             7.3             7.5
# Jannali                                                4.9             4.2
# Oyster Bay                                             5.9             4.9
# Como (NSW)                                             5.2             4.6
# Kareela                                                5.9             7.4
# Kirrawee                                               5.1             4.9
# Sutherland (NSW)                                       4.4             3.8
# Loftus                                                 4.6             5.2
# Engadine                                               4.6             5.6
# Yarrawarrah                                            9.4             5.8
# Woronora Heights                                       7.5             4.3
#
# Age                                        70-74 years (%) 75-79 years (%)  \
# Lower Boro                                             6.9             3.5
# New South Wales                                        3.9             2.9
# Australia                                              3.8             2.8
# Oallen                                                 6.0             2.3
# Braidwood                                              7.2             5.7
# Majors Creek (NSW)                                     6.4             3.6
# Araluen (NSW)                                         10.9             3.4
# Reidsdale                                              6.2             0.0
# Bombay                                                 2.4             3.2
# Warri                                                  3.7             3.7
# Manar                                                  3.6             0.0
# Mongarlowe                                             5.6             5.6
# Karabar                                                3.3             2.6
# Queanbeyan                                             3.2             2.8
# Crestwood                                              2.9             2.2
# Queanbeyan East                                        2.1             1.6
# Greenleigh                                             5.7             3.2
# The Ridgeway                                          13.0             4.3
# Bungendore                                             2.5             1.1
# Sutton (NSW)                                           4.1             2.2
# Carwoola                                               3.0             1.7
# Hoskinstown                                            5.4             5.4
# Captains Flat                                          2.0             1.7
# Burra (Queanbeyan-Palerang Regional - NSW)             5.1             3.2
# Mount Fairy                                            6.7             3.3
# Mulloon                                                6.5             2.2
# Royalla                                                1.7             0.9
# Primrose Valley                                        2.1             2.1
# Urila                                                  0.0             2.2
# Tarago                                                 4.7             4.5
# ...                                                    ...             ...
# Caringbah South                                        4.1             3.2
# Dolans Bay                                             5.3             1.0
# Kurnell                                                4.1             2.1
# Greenhills Beach                                       0.9             0.4
# Cronulla                                               4.0             2.5
# Bundeena                                               5.9             4.0
# Maianbar                                               4.8             2.2
# Woolooware                                             3.3             2.7
# Lilli Pilli (Sutherland Shire - NSW)                   3.3             2.9
# Port Hacking                                           4.1             3.2
# Burraneer                                              3.8             2.5
# Heathcote (NSW)                                        4.1             3.6
# Waterfall                                              4.1             3.3
# Illawong                                               3.1             2.4
# Alfords Point                                          2.2             1.3
# Barden Ridge                                           2.1             1.1
# Menai                                                  2.8             1.9
# Bangor (NSW)                                           3.9             2.1
# Woronora                                               4.4             1.9
# Bonnet Bay                                             5.5             2.5
# Jannali                                                2.9             2.3
# Oyster Bay                                             3.6             2.1
# Como (NSW)                                             3.0             1.6
# Kareela                                                7.5             3.7
# Kirrawee                                               4.2             3.7
# Sutherland (NSW)                                       3.3             2.4
# Loftus                                                 4.6             3.7
# Engadine                                               5.2             2.7
# Yarrawarrah                                            3.6             3.1
# Woronora Heights                                       2.3             1.0
#
# Age                                        80-84 years (%)  \
# Lower Boro                                             1.7
# New South Wales                                        2.1
# Australia                                              2.0
# Oallen                                                 0.0
# Braidwood                                              2.4
# Majors Creek (NSW)                                     1.6
# Araluen (NSW)                                          1.7
# Reidsdale                                              4.7
# Bombay                                                 4.0
# Warri                                                  0.0
# Manar                                                  0.0
# Mongarlowe                                             0.0
# Karabar                                                1.2
# Queanbeyan                                             2.4
# Crestwood                                              2.2
# Queanbeyan East                                        1.6
# Greenleigh                                             0.9
# The Ridgeway                                           0.0
# Bungendore                                             0.9
# Sutton (NSW)                                           1.1
# Carwoola                                               1.0
# Hoskinstown                                            0.0
# Captains Flat                                          0.5
# Burra (Queanbeyan-Palerang Regional - NSW)             1.5
# Mount Fairy                                            0.0
# Mulloon                                                0.0
# Royalla                                                0.8
# Primrose Valley                                        0.0
# Urila                                                  0.0
# Tarago                                                 0.0
# ...                                                    ...
# Caringbah South                                        2.9
# Dolans Bay                                             2.3
# Kurnell                                                1.6
# Greenhills Beach                                       0.0
# Cronulla                                               2.3
# Bundeena                                               1.8
# Maianbar                                               0.6
# Woolooware                                             2.2
# Lilli Pilli (Sutherland Shire - NSW)                   2.2
# Port Hacking                                           2.0
# Burraneer                                              1.9
# Heathcote (NSW)                                        3.3
# Waterfall                                              1.4
# Illawong                                               1.3
# Alfords Point                                          0.9
# Barden Ridge                                           0.6
# Menai                                                  0.9
# Bangor (NSW)                                           1.5
# Woronora                                               1.3
# Bonnet Bay                                             1.6
# Jannali                                                2.1
# Oyster Bay                                             1.6
# Como (NSW)                                             1.4
# Kareela                                                1.7
# Kirrawee                                               3.2
# Sutherland (NSW)                                       1.9
# Loftus                                                 2.4
# Engadine                                               1.7
# Yarrawarrah                                            0.8
# Woronora Heights                                       0.4
#
# Age                                        85 years and over (%)
# Lower Boro                                                   0.0
# New South Wales                                              2.2
# Australia                                                    2.1
# Oallen                                                       0.0
# Braidwood                                                    3.0
# Majors Creek (NSW)                                           1.6
# Araluen (NSW)                                                4.0
# Reidsdale                                                    2.3
# Bombay                                                       4.8
# Warri                                                        0.0
# Manar                                                        0.0
# Mongarlowe                                                   2.4
# Karabar                                                      1.0
# Queanbeyan                                                   3.8
# Crestwood                                                    1.7
# Queanbeyan East                                              1.2
# Greenleigh                                                   0.4
# The Ridgeway                                                 1.9
# Bungendore                                                   0.6
# Sutton (NSW)                                                 0.7
# Carwoola                                                     0.6
# Hoskinstown                                                  0.0
# Captains Flat                                                0.5
# Burra (Queanbeyan-Palerang Regional - NSW)                   0.0
# Mount Fairy                                                  1.4
# Mulloon                                                      0.0
# Royalla                                                      0.3
# Primrose Valley                                              0.0
# Urila                                                        0.0
# Tarago                                                       0.7
# ...                                                          ...
# Caringbah South                                              2.8
# Dolans Bay                                                   2.7
# Kurnell                                                      0.5
# Greenhills Beach                                             0.0
# Cronulla                                                     2.6
# Bundeena                                                     2.1
# Maianbar                                                     0.0
# Woolooware                                                   2.3
# Lilli Pilli (Sutherland Shire - NSW)                         1.7
# Port Hacking                                                 1.7
# Burraneer                                                    2.8
# Heathcote (NSW)                                              4.5
# Waterfall                                                    0.6
# Illawong                                                     1.8
# Alfords Point                                                1.0
# Barden Ridge                                                 1.7
# Menai                                                        0.9
# Bangor (NSW)                                                 2.8
# Woronora                                                     0.7
# Bonnet Bay                                                   0.7
# Jannali                                                      3.8
# Oyster Bay                                                   1.7
# Como (NSW)                                                   1.7
# Kareela                                                      1.3
# Kirrawee                                                     4.6
# Sutherland (NSW)                                             3.1
# Loftus                                                       1.9
# Engadine                                                     1.7
# Yarrawarrah                                                  0.6
# Woronora Heights                                             0.5
#
# [2600 rows x 38 columns]

# %%
errortables[15]
table = errortables[15]
table.find_all('tr')[1].find_all('td')[0]
values = []
for row in table.find_all('tr')[1:]:
    try:
        record = [row.find_all('td')[0].text]
        records = record + [convert(x.text) for x in row.find_all('td')[1:]]
        if len(records) == 1:
            continue
        values.append(records)
    except IndexError:
        print(record)
        print(row.find('td'))
# Out:
# ['Total families']
# None

# %%
# open pickle file
with open('source{}.pkl'.format(year), 'rb') as f:
    source = pickle.load(f)

# %%
with open('source2001.pkl', 'rb') as f:
    d = pickle.load(f)
    
# soup = d['Burwood']
soup = bs(d2016['Burwood'], 'html')
tables = soup.find_all('table')

parse_common_table(tables[16], '2016')
# Out:
# EmploymentPeople who reported being in the labour force, aged 15 years and over Worked full-time  \
# Burwood (NSW)                                                                               4289
# New South Wales                                                                      2.13452e+06
# Australia                                                                            6.62306e+06
#
# EmploymentPeople who reported being in the labour force, aged 15 years and over Worked part-time  \
# Burwood (NSW)                                                                               2536
# New South Wales                                                                      1.07115e+06
# Australia                                                                             3.4915e+06
#
# EmploymentPeople who reported being in the labour force, aged 15 years and over Away from work  \
# Burwood (NSW)                                                                              362
# New South Wales                                                                         174654
# Australia                                                                               569276
#
# EmploymentPeople who reported being in the labour force, aged 15 years and over Unemployed  \
# Burwood (NSW)                                                                          795
# New South Wales                                                                     225546
# Australia                                                                           787452
#
# EmploymentPeople who reported being in the labour force, aged 15 years and over Worked full-time (%)  \
# Burwood (NSW)                                                                                   53.7
# New South Wales                                                                                 59.2
# Australia                                                                                       57.7
#
# EmploymentPeople who reported being in the labour force, aged 15 years and over Worked part-time (%)  \
# Burwood (NSW)                                                                                   31.8
# New South Wales                                                                                 29.7
# Australia                                                                                       30.4
#
# EmploymentPeople who reported being in the labour force, aged 15 years and over Away from work (%)  \
# Burwood (NSW)                                                                                  4.5
# New South Wales                                                                                4.8
# Australia                                                                                      5.0
#
# EmploymentPeople who reported being in the labour force, aged 15 years and over Unemployed (%)
# Burwood (NSW)                                                                             10.0
# New South Wales                                                                            6.3
# Australia                                                                                  6.9

# %%
def convert(val):
    """Convert a value to numeric if it is."""
    val = val.replace(',', '')
    val = float(val) if val.isdigit() else val
    return val

def get_values_2006(table):
    """Parse table for 2006 html page."""
    # find values
    values = []
    for row in table.find_all('tr')[1:]:
        if row.find('td') is None:
            continue
        record = [row.find_all('td')[0].text]
        records = record + [convert(x.text) for x in row.find_all('td')[1:]]
        if len(records) == 1:
            continue
        values.append(records)
    return values

def get_values_2016(table):
    """Parse table for 2016 html page."""
    # find values
    values = []
    for row in table.find_all('tr')[1:]:
        if row.find('td') is None:
            continue
        record = [row.find_all('th')[0].text]
        records = record + [convert(x.text) for x in row.find_all('td')]
        values.append(records)
    return values

def parse_common_table(table, year):
    """Parse table that has common row names across different suburbs."""
    # find column names
    row = table.find_all('tr')[0]
    columns = [x.text for x in row.find_all('th')]
    for i, x in enumerate(columns):
        if x == '%':
            columns[i] = columns[i - 1] + " (%)"
    
    if year != '2016':
        values = get_values_2006(table)
    else:
        values = get_values_2016(table)
    
    data = pd.DataFrame(values, columns=columns).T
    data.columns = data.iloc[0]
    data = data.iloc[1:]

    # create double columns for percentage
    columns = list(data.columns)
    newcolumns = [x + ' (%)' for x in columns]
    for x in newcolumns:
        data[x] = None
        
    # find percentage rows and fill in value
    index = [x for x in data.index if '%' in x]
    for i in index:
        record = data.loc[i]
        rowname = ' '.join(i.split(' ')[:-1])
        for x in columns:
            data.at[rowname, x + ' (%)'] =  record[x]
    
    # drop those rows
    data = data.drop(index)
    return data

# %%
ages = tables[4]
# tables[4]

table = tables[4]

# find column names
row = table.find_all('tr')[0]
columns = [x.text for x in row.find_all('th')]
for i, x in enumerate(columns):
    if x == '%':
        columns[i] = columns[i - 1] + " (%)"
columns

values = get_values_2006(table)

values

data = pd.DataFrame(values, columns=columns).T
data.columns = data.iloc[0]
data = data.iloc[1:]

data
# Out:
# Median weekly incomes Personal Family Household Personal (%) Family (%)  \
# Burwood                    370   1115      1005           --         --
# Australia                  466   1171      1027           --         --
#
# Median weekly incomes Household (%)
# Burwood                          --
# Australia                        --

# %%
# Out:
# Iteration i=0
# Abbotsbury
# Iteration i=100
# Burwood
# Iteration i=200
# Dover Heights
# Index is out of tables length
# Iteration i=300
# Heathcote
# Index is out of tables length
# Index is out of tables length
# Iteration i=400
# Macquarie Park
# Index is out of tables length
# Index is out of tables length
# Iteration i=500
# Oatlands
# Index is out of tables length
# Iteration i=600
# Springfield
# Index is out of tables length
# Index is out of tables length
# Iteration i=700
# Whitebridge

# %%
suburb = 'Hillsborough'
print(suburb)
soup = bs(txt, 'html')
# find all tables
tables = soup.find_all('table')
# tables[0].find_all('td')[0].text
len(tables)
# sdata = parse_common_table(tables[index], '2016')
# Out:
# Hillsborough
# 3

# %%
pd.concat(group, axis=0).drop_duplicates()
# Out:
# Social marital statusPeople aged 15 years and over Registered marriage  \
# Abbotsbury                                                        1827
# New South Wales                                            2.61263e+06
# Australia                                                  8.00114e+06
# Abbotsford (NSW)                                                  2080
# Acacia Gardens                                                    1689
# Adamstown                                                         1794
# Adamstown Heights                                                 2335
# Airds                                                              408
# Albion Park                                                       5019
# Albion Park Rail                                                  2280
# Alexandria                                                        1799
# Alfords Point                                                     1505
# Allambie Heights                                                  2829
# Allawah                                                           2229
# Ambarvale                                                         2158
# Annandale (NSW)                                                   2558
# Argenton                                                           352
# Arncliffe                                                         3416
# Artarmon                                                          3526
# Ashbury                                                           1396
# Ashcroft                                                           873
# Ashfield (NSW)                                                    7377
# Asquith                                                           1445
# Auburn (NSW)                                                     12624
# Austinmer                                                          955
# Avoca Beach                                                       1797
# Balgowlah                                                         2895
# Balgowlah Heights                                                 1455
# Balgownie                                                         2262
# Balmain                                                           3271
# ...                                                                ...
# Willoughby East                                                    776
# Windale                                                            636
# Windang                                                            947
# Winmalee                                                          2554
# Winston Hills                                                     5180
# Wollongong                                                        4616
# Wollstonecraft                                                    2746
# Wombarra                                                           326
# Woodbine (NSW)                                                    1043
# Woodcroft (NSW)                                                   2982
# Woodpark                                                           572
# Woodrising                                                         376
# Woollahra                                                         2215
# Woolloomooloo                                                      627
# Woolooware                                                        1486
# Woolwich                                                           347
# Woonona                                                           4502
# Woronora                                                           898
# Woronora Heights                                                  1372
# Woy Woy                                                           3168
# Woy Woy Bay                                                        192
# Wyoming                                                           3162
# Wyong                                                             1185
# Wyongah                                                            647
# Yagoona                                                           6161
# Yarrawarrah                                                       1325
# Yattalunga (NSW)                                                   231
# Yennora                                                            447
# Yowie Bay                                                         1379
# Zetland                                                           2052
#
# Social marital statusPeople aged 15 years and over De facto marriage  \
# Abbotsbury                                                       134
# New South Wales                                               506133
# Australia                                                1.75173e+06
# Abbotsford (NSW)                                                 410
# Acacia Gardens                                                   133
# Adamstown                                                        572
# Adamstown Heights                                                273
# Airds                                                            181
# Albion Park                                                      945
# Albion Park Rail                                                 555
# Alexandria                                                      1776
# Alfords Point                                                     90
# Allambie Heights                                                 334
# Allawah                                                          262
# Ambarvale                                                        521
# Annandale (NSW)                                                 1215
# Argenton                                                         139
# Arncliffe                                                        736
# Artarmon                                                         664
# Ashbury                                                          141
# Ashcroft                                                         140
# Ashfield (NSW)                                                  1809
# Asquith                                                          113
# Auburn (NSW)                                                     753
# Austinmer                                                        200
# Avoca Beach                                                      269
# Balgowlah                                                        693
# Balgowlah Heights                                                115
# Balgownie                                                        293
# Balmain                                                         1137
# ...                                                              ...
# Willoughby East                                                   74
# Windale                                                          266
# Windang                                                          170
# Winmalee                                                         436
# Winston Hills                                                    465
# Wollongong                                                      1552
# Wollstonecraft                                                  1052
# Wombarra                                                          93
# Woodbine (NSW)                                                   164
# Woodcroft (NSW)                                                  198
# Woodpark                                                          74
# Woodrising                                                        93
# Woollahra                                                        762
# Woolloomooloo                                                    535
# Woolooware                                                       279
# Woolwich                                                          53
# Woonona                                                          762
# Woronora                                                         151
# Woronora Heights                                                  89
# Woy Woy                                                          839
# Woy Woy Bay                                                       41
# Wyoming                                                          755
# Wyong                                                            292
# Wyongah                                                          166
# Yagoona                                                          550
# Yarrawarrah                                                      117
# Yattalunga (NSW)                                                  38
# Yennora                                                           48
# Yowie Bay                                                        113
# Zetland                                                         1726
#
# Social marital statusPeople aged 15 years and over  Not married  \
# Abbotsbury                                                 1412
# New South Wales                                     2.29089e+06
# Australia                                           7.02497e+06
# Abbotsford (NSW)                                           1623
# Acacia Gardens                                              974
# Adamstown                                                  2124
# Adamstown Heights                                          1329
# Airds                                                      1265
# Albion Park                                                3497
# Albion Park Rail                                           2147
# Alexandria                                                 2952
# Alfords Point                                               897
# Allambie Heights                                           1793
# Allawah                                                    2102
# Ambarvale                                                  2518
# Annandale (NSW)                                            2905
# Argenton                                                    529
# Arncliffe                                                  3844
# Artarmon                                                   2889
# Ashbury                                                     967
# Ashcroft                                                   1328
# Ashfield (NSW)                                             9019
# Asquith                                                     911
# Auburn (NSW)                                              14346
# Austinmer                                                   653
# Avoca Beach                                                1148
# Balgowlah                                                  2088
# Balgowlah Heights                                           707
# Balgownie                                                  1659
# Balmain                                                    3058
# ...                                                         ...
# Willoughby East                                             377
# Windale                                                    1436
# Windang                                                    1005
# Winmalee                                                   1583
# Winston Hills                                              2993
# Wollongong                                                 7873
# Wollstonecraft                                             2761
# Wombarra                                                    226
# Woodbine (NSW)                                              749
# Woodcroft (NSW)                                            1911
# Woodpark                                                    438
# Woodrising                                                  389
# Woollahra                                                  2290
# Woolloomooloo                                              1795
# Woolooware                                                 1185
# Woolwich                                                    212
# Woonona                                                    3517
# Woronora                                                    557
# Woronora Heights                                            803
# Woy Woy                                                    4070
# Woy Woy Bay                                                  93
# Wyoming                                                    3287
# Wyong                                                      1621
# Wyongah                                                     629
# Yagoona                                                    5970
# Yarrawarrah                                                 642
# Yattalunga (NSW)                                            120
# Yennora                                                     575
# Yowie Bay                                                   838
# Zetland                                                    4419
#
# Social marital statusPeople aged 15 years and over Registered marriage (%)  \
# Abbotsbury                                                            54.2
# New South Wales                                                       48.3
# Australia                                                             47.7
# Abbotsford (NSW)                                                      50.6
# Acacia Gardens                                                        60.4
# Adamstown                                                             40.0
# Adamstown Heights                                                     59.3
# Airds                                                                 22.0
# Albion Park                                                           53.0
# Albion Park Rail                                                      45.8
# Alexandria                                                            27.6
# Alfords Point                                                         60.4
# Allambie Heights                                                      57.1
# Allawah                                                               48.5
# Ambarvale                                                             41.5
# Annandale (NSW)                                                       38.3
# Argenton                                                              34.5
# Arncliffe                                                             42.7
# Artarmon                                                              49.8
# Ashbury                                                               55.8
# Ashcroft                                                              37.3
# Ashfield (NSW)                                                        40.5
# Asquith                                                               58.5
# Auburn (NSW)                                                          45.5
# Austinmer                                                             52.8
# Avoca Beach                                                           55.9
# Balgowlah                                                             51.0
# Balgowlah Heights                                                     63.9
# Balgownie                                                             53.7
# Balmain                                                               43.8
# ...                                                                    ...
# Willoughby East                                                       63.2
# Windale                                                               27.2
# Windang                                                               44.6
# Winmalee                                                              55.8
# Winston Hills                                                         60.0
# Wollongong                                                            32.9
# Wollstonecraft                                                        41.9
# Wombarra                                                              50.5
# Woodbine (NSW)                                                        53.3
# Woodcroft (NSW)                                                       58.6
# Woodpark                                                              52.8
# Woodrising                                                            43.8
# Woollahra                                                             42.1
# Woolloomooloo                                                         21.2
# Woolooware                                                            50.4
# Woolwich                                                              56.7
# Woonona                                                               51.3
# Woronora                                                              55.9
# Woronora Heights                                                      60.6
# Woy Woy                                                               39.2
# Woy Woy Bay                                                           58.9
# Wyoming                                                               43.9
# Wyong                                                                 38.3
# Wyongah                                                               44.9
# Yagoona                                                               48.6
# Yarrawarrah                                                           63.6
# Yattalunga (NSW)                                                      59.4
# Yennora                                                               41.8
# Yowie Bay                                                             59.2
# Zetland                                                               25.0
#
# Social marital statusPeople aged 15 years and over De facto marriage (%)  \
# Abbotsbury                                                           4.0
# New South Wales                                                      9.4
# Australia                                                           10.4
# Abbotsford (NSW)                                                    10.0
# Acacia Gardens                                                       4.8
# Adamstown                                                           12.7
# Adamstown Heights                                                    6.9
# Airds                                                                9.8
# Albion Park                                                         10.0
# Albion Park Rail                                                    11.1
# Alexandria                                                          27.2
# Alfords Point                                                        3.6
# Allambie Heights                                                     6.7
# Allawah                                                              5.7
# Ambarvale                                                           10.0
# Annandale (NSW)                                                     18.2
# Argenton                                                            13.6
# Arncliffe                                                            9.2
# Artarmon                                                             9.4
# Ashbury                                                              5.6
# Ashcroft                                                             6.0
# Ashfield (NSW)                                                       9.9
# Asquith                                                              4.6
# Auburn (NSW)                                                         2.7
# Austinmer                                                           11.1
# Avoca Beach                                                          8.4
# Balgowlah                                                           12.2
# Balgowlah Heights                                                    5.1
# Balgownie                                                            7.0
# Balmain                                                             15.2
# ...                                                                  ...
# Willoughby East                                                      6.0
# Windale                                                             11.4
# Windang                                                              8.0
# Winmalee                                                             9.5
# Winston Hills                                                        5.4
# Wollongong                                                          11.1
# Wollstonecraft                                                      16.0
# Wombarra                                                            14.4
# Woodbine (NSW)                                                       8.4
# Woodcroft (NSW)                                                      3.9
# Woodpark                                                             6.8
# Woodrising                                                          10.8
# Woollahra                                                           14.5
# Woolloomooloo                                                       18.1
# Woolooware                                                           9.5
# Woolwich                                                             8.7
# Woonona                                                              8.7
# Woronora                                                             9.4
# Woronora Heights                                                     3.9
# Woy Woy                                                             10.4
# Woy Woy Bay                                                         12.6
# Wyoming                                                             10.5
# Wyong                                                                9.4
# Wyongah                                                             11.5
# Yagoona                                                              4.3
# Yarrawarrah                                                          5.6
# Yattalunga (NSW)                                                     9.8
# Yennora                                                              4.5
# Yowie Bay                                                            4.8
# Zetland                                                             21.1
#
# Social marital statusPeople aged 15 years and over Not married (%)
# Abbotsbury                                                    41.9
# New South Wales                                               42.3
# Australia                                                     41.9
# Abbotsford (NSW)                                              39.5
# Acacia Gardens                                                34.8
# Adamstown                                                     47.3
# Adamstown Heights                                             33.8
# Airds                                                         68.2
# Albion Park                                                   37.0
# Albion Park Rail                                              43.1
# Alexandria                                                    45.2
# Alfords Point                                                 36.0
# Allambie Heights                                              36.2
# Allawah                                                       45.8
# Ambarvale                                                     48.5
# Annandale (NSW)                                               43.5
# Argenton                                                      51.9
# Arncliffe                                                     48.1
# Artarmon                                                      40.8
# Ashbury                                                       38.6
# Ashcroft                                                      56.7
# Ashfield (NSW)                                                49.5
# Asquith                                                       36.9
# Auburn (NSW)                                                  51.7
# Austinmer                                                     36.1
# Avoca Beach                                                   35.7
# Balgowlah                                                     36.8
# Balgowlah Heights                                             31.0
# Balgownie                                                     39.4
# Balmain                                                       41.0
# ...                                                            ...
# Willoughby East                                               30.7
# Windale                                                       61.4
# Windang                                                       47.4
# Winmalee                                                      34.6
# Winston Hills                                                 34.6
# Wollongong                                                    56.1
# Wollstonecraft                                                42.1
# Wombarra                                                      35.0
# Woodbine (NSW)                                                38.3
# Woodcroft (NSW)                                               37.5
# Woodpark                                                      40.4
# Woodrising                                                    45.3
# Woollahra                                                     43.5
# Woolloomooloo                                                 60.7
# Woolooware                                                    40.2
# Woolwich                                                      34.6
# Woonona                                                       40.1
# Woronora                                                      34.7
# Woronora Heights                                              35.5
# Woy Woy                                                       50.4
# Woy Woy Bay                                                   28.5
# Wyoming                                                       45.6
# Wyong                                                         52.3
# Wyongah                                                       43.6
# Yagoona                                                       47.1
# Yarrawarrah                                                   30.8
# Yattalunga (NSW)                                              30.8
# Yennora                                                       53.7
# Yowie Bay                                                     36.0
# Zetland                                                       53.9
#
# [729 rows x 6 columns]

# %%
table = tables[9]
# find column names
row = table.find_all('tr')[0]
columns = [x.text for x in row.find_all('th')]
for i, x in enumerate(columns):
    if x == '%':
        columns[i] = columns[i - 1] + " (%)"
# find values
values = []
for row in table.find_all('tr')[1:]:
    record = [row.find_all('th')[0].text]
    records = record + [convert(x.text) for x in row.find_all('td')]
    values.append(records)

table
# Out:
# <table id="ancestryTable"><!-- Ancestry, top responses -->
# <tr>
# <th class="firstCol topRow" scope="col"><a class="dictionaryLink" href="/ausstats/abs@.nsf/Lookup/2901.0Chapter20802016" target="_blank" title="A person's ancestry, when used in conjunction with the person's country of birth and whether the person's parents were born in Australia or overseas, provides a good indication of the ethnic background of first and second generation Australians.">Ancestry, top responses</a></th>
# <th class="geoCol" scope="col">Burwood (NSW)</th>
# <th class="percentCol" scope="col">%</th>
# <th class="geoCol supressCol" scope="col">New South Wales</th>
# <th class="percentCol supressCol" scope="col">%</th>
# <th class="geoCol" scope="col">Australia</th>
# <th class="percentCol" scope="col">%</th>
# </tr>
# </table>

# %%
scripts = soup.find_all('script')
scripts[9].attrs
# Out:
# {'type': 'text/javascript'}

# %%
javascript = [x for x in scripts if 'src' not in x.attrs and 'type' in x.attrs
              and x.attrs['type'] == 'text/javascript'][0]

# javascript

# %%
re.compile("var ancestryData = \[\];").findall(javascript.text)
# Out:
# []

# %%
float(people.find_all('td')[1].text.replace(',', ''))
# Out:
# 21260.0
