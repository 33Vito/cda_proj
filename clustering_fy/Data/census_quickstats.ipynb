# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
import pickle
import matplotlib.pyplot as pl
import re
import os
from tqdm import tqdm

# %%
url_format = 'https://quickstats.censusdata.abs.gov.au/census_services/getproduct/census/2016/quickstat/SSC10098'


# open pickle file
with open('source/source2016.pkl', 'rb') as f:
    source = pickle.load(f)

# %%
soup = bs(source['Ashfield'], 'html')
tables = soup.find_all('table')

# %% [markdown]
# # Parse Quick Stats from 2001 to 2016

# %%
tables[4]

get_quickstat_2016(tables, 'Ashfield').T
# Out:
#            People   Male  Female  Median age  Families  \
# Ashfield  23841.0  0.494   0.506        34.0    5715.0
#
#           Average children per family for families with children  \
# Ashfield                                                1.5
#
#           Average children per family for all families  All private dwellings  \
# Ashfield                                           0.5                 9731.0
#
#           Average people per household  Median weekly household income  \
# Ashfield                           2.5                          1632.0
#
#           Median monthly mortgage repayments  Median weekly rent  \
# Ashfield                              2058.0               440.0
#
#           Average motor vehicles per dwelling
# Ashfield                                  1.2

# %%
quickstats = {}

for year in ['2001', '2006', '2011', '2016']:
    print('Year={}'.format(year))
   
    # open pickle file
    with open('source{}.pkl'.format(year), 'rb') as f:
        source = pickle.load(f)
    
    # parse quick summary
    stats = []
    for i, (suburb, txt) in enumerate(source.items()):
        if i % 100 == 0:
            print('Quickstat Iteration={}'.format(i))
        soup = bs(txt, 'html')
        # find all tables
        tables = soup.find_all('table')
        # parse quick summary
        try:
            if year == '2016':
                stats.append(get_quickstat_2016(tables, suburb))
            else:
                stats.append(get_quickstat_2011(tables, suburb))
        except ValueError as e:
            print(suburb)
            print(e)
    # integrate all in one table
    quickstats[year] = pd.concat(stats, axis=1).T
# Out:
# Year=2011
# Quickstat Iteration=0
# Quickstat Iteration=100
# Quickstat Iteration=200
# Quickstat Iteration=300
# Hinchinbrook
# Length mismatch: Expected axis has 0 elements, new values have 1 elements
# Quickstat Iteration=400
# Quickstat Iteration=500
# Quickstat Iteration=600
# Quickstat Iteration=700
# Wickham
# Length mismatch: Expected axis has 0 elements, new values have 1 elements
# Year=2016
# Quickstat Iteration=0
# Quickstat Iteration=100
# Quickstat Iteration=200
# Dural
# Length mismatch: Expected axis has 0 elements, new values have 1 elements
# Quickstat Iteration=300
# Quickstat Iteration=400
# Quickstat Iteration=500
# Punchbowl
# Length mismatch: Expected axis has 0 elements, new values have 1 elements
# Quickstat Iteration=600
# Quickstat Iteration=700

# %%
# Save to disk
for key, df in quickstats.items():
    path = 'Quickstat_{}.csv'.format(key)
    df.to_csv(path)

# %%
def get_quickstat_2011(tables, suburn):
    """Get quick stats for each suburb at each year."""
    quickstat = {}
    keys = []
    vals = []

    # parse quick summary
    for people in tables[1: 4]:
        for td in people.find_all('td'):
            if len(td.attrs) > 0 and 'class' in td.attrs and td.attrs['class'] == ['summaryData']:
                vals.append(float(td.text.replace(',', '').replace('$', '')))
            else:
                keys.append(td.text)

    quickstat = {k: [v] for k, v in zip(keys, vals)}
    data = pd.DataFrame.from_dict(quickstat).T
    data.columns = [suburb]
    return data

def get_quickstat_2016(tables, suburb):
    """Get quick stats for each suburb at each year."""
    quickstat = {}
    keys = []
    vals = []

    # parse quick summary
    for people in tables[0: 3]:
        for th, td in zip(people.find_all('th'), people.find_all('td')):
            if td.text == '':
                continue  # average children per family
            value = td.text.replace(',', '').replace('$', '')
            if th.text in ['for families with children', 'for all families']:
                k = 'Average children per family ' + th.text
            else:
                k = th.text
            if '%' in value:
                value = float(value.replace('%', '')) * 0.01
            else:
                value = float(value)
            # append values
            keys.append(k)
            vals.append(value)

    quickstat = {k: [v] for k, v in zip(keys, vals)}
    data = pd.DataFrame.from_dict(quickstat).T
    data.columns = [suburb]
    return data

# %% [markdown]
# # Parse Common Table from 2001 to 2016

# %% [markdown]
# ### Table mapping

# %%
common_map = {}
uncommon_map = {}

for year in ['2001', '2006', '2011', '2016']:
    with open('source/source{}.pkl'.format(year), 'rb') as f:
        d = pickle.load(f)
    soup = bs(d['Burwood'], 'html')
    tables = soup.find_all('table')

    cmap = {}
    ucmap = {}
    for i, tb in enumerate(tables):
        try:
            z = re.search(r'(\<\!--).+(-->)', str(tb))
            name = z.group().replace('<!-- ', '').replace('-->', '').strip()
        except AttributeError:
            name = tb.text.strip().split('\n')[0]
        try:
            df = parse_common_table(tb, year)
            if len(df.columns) == 0:
                ucmap[i] = name
            else:
                cmap[i] = name
        except:
            cmap[i] = name
    # append to overall mapping
    common_map[year] = cmap
    uncommon_map[year] = ucmap

# %%
non2016 = [0, 1, 2, 3, 4]
yes2016 = [0, 1, 2, 3]
for year in common_map:
    exclusion = yes2016 if year == '2016' else non2016
    common_map[year] = {k: v for k, v in common_map[year].items() if k not in exclusion and v != ''}

# country of birth should be taken out
for year in common_map:
    c = common_map[year]
    topop = None
    for k, v in c.items():
        if v == 'Country of birth':
            uncommon_map[year][k] = v
            topop = k
    common_map[year].pop(k)
uncommon_map
# Out:
# {'2001': {9: 'Religious affiliation, top responses',
#   10: 'Language, top responses (other than English)',
#   12: 'Occupation',
#   13: 'Industry of employment, top responses',
#   8: 'Country of birth'},
#  '2006': {9: 'Religious affiliation, top responses',
#   10: 'Language, top responses (other than English)',
#   12: 'Occupation',
#   13: 'Industry of employment, top responses',
#   21: 'Household composition',
#   8: 'Country of birth'},
#  '2011': {11: 'Ancestry, top responses',
#   14: 'Religious affiliation, top responses',
#   15: 'Language, top responses (other than English)',
#   19: 'Occupation',
#   20: 'Industry of employment, top responses',
#   22: 'Travel to work, top responses',
#   12: 'Country of birth'},
#  '2016': {9: 'Ancestry, top responses',
#   12: 'Country of birth of father',
#   13: 'Country of birth of mother',
#   14: 'Religious affiliation',
#   15: 'Language, top responses5',
#   18: 'Occupation',
#   19: 'Industry of employment',
#   21: 'Travel to work',
#   10: 'Country of birth'}}

# %% [markdown]
# It is consistent that we need to parse table 4 to table 39 for all 4 years.
#
# ### Parse common tables

# %%
commontables = {}

errortables = None
dataroot = 'census_data'
if not os.path.exists(dataroot):
    os.mkdir(dataroot)
    
for year in ['2001', '2006', '2011', '2016']: 
    # open pickle file
    with open('source/source{}.pkl'.format(year), 'rb') as f:
        source = pickle.load(f)
    
    # iterate all common tables
    for index, tablename in common_map[year].items():
        name = '{}_{}.csv'.format(year, tablename).replace(' ', '_')
        name = name.replace('/', '_')
        path = os.path.join(dataroot, name)
        print('Year={} Table={}'.format(year, tablename))
        if os.path.exists(path):
            continue
        group = []
        for i, (suburb, txt) in enumerate(source.items()):
            if i % 100 == 0:
                print('    Iteration i={}'.format(i))
            soup = bs(txt, 'html')
            # find all tables
            tables = soup.find_all('table')
            try:
                sdata = parse_common_table(tables[index], year)
                group.append(sdata)
            except IndexError:
                print('  Error with {}, index={}'.format(suburb, index))
                errortables = tables
                continue
            
        df = pd.concat(group, axis=0).drop_duplicates()
        print('Saving to', path)
        df.to_csv(path)
# Out:
# Year=2001 Table=Age
# Year=2001 Table=Selected characteristics
# Year=2001 Table=Registered marital status
# Year=2001 Table=Country of birth
# Year=2001 Table=Employment
# Year=2001 Table=Family type
# Year=2001 Table=Dwelling type
# Year=2001 Table=Dwelling structure
# Year=2001 Table=Tenure
# Year=2001 Table=Landlord type
# Year=2006 Table=Age
# Year=2006 Table=Selected characteristics
# Year=2006 Table=Registered marital status
# Year=2006 Table=Country of birth
# Year=2006 Table=Employment
# Year=2006 Table=Median weekly incomes
# Year=2006 Table=Family composition
# Year=2006 Table=Dwelling structure
# Year=2006 Table=Tenure
# Year=2006 Table=Landlord type
# Year=2011 Table=Age
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
# Saving to census_data/2011_Age.csv
# Year=2011 Table=Registered marital status
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
# Saving to census_data/2011_Registered_marital_status.csv
# Year=2011 Table=Median age by registered marital status
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
# Saving to census_data/2011_Median_age_by_registered_marital_status.csv
# Year=2011 Table=Social marital status
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
# Saving to census_data/2011_Social_marital_status.csv
# Year=2011 Table=Median age by social marital status
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
# Saving to census_data/2011_Median_age_by_social_marital_status.csv
# Year=2011 Table=Education
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
# Saving to census_data/2011_Education.csv
# Year=2011 Table=Country of birth
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
# Saving to census_data/2011_Country_of_birth.csv
# Year=2011 Table=Birthplace of parents, stated responses
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
# Saving to census_data/2011_Birthplace_of_parents,_stated_responses.csv
# Year=2011 Table=Employment
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
# Saving to census_data/2011_Employment.csv
# Year=2011 Table=Employment - hours worked
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
# Saving to census_data/2011_Employment_-_hours_worked.csv
# Year=2011 Table=Median age by employment status
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
# Saving to census_data/2011_Median_age_by_employment_status.csv
# Year=2011 Table=Median weekly incomes
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
# Saving to census_data/2011_Median_weekly_incomes.csv
# Year=2011 Table=Unpaid work
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
# Saving to census_data/2011_Unpaid_work.csv
# Year=2011 Table=Unpaid domestic work, number of hours
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
# Saving to census_data/2011_Unpaid_domestic_work,_number_of_hours.csv
# Year=2011 Table=Family composition
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
# Saving to census_data/2011_Family_composition.csv
# Year=2011 Table=Single (or lone) parents
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
# Saving to census_data/2011_Single_(or_lone)_parents.csv
# Year=2011 Table=Median family income, couple families with two incomes
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
# Saving to census_data/2011_Median_family_income,_couple_families_with_two_incomes.csv
# Year=2011 Table=Employment status of couple families
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
# Saving to census_data/2011_Employment_status_of_couple_families.csv
# Year=2011 Table=Dwelling type
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
# Saving to census_data/2011_Dwelling_type.csv
# Year=2011 Table=Dwelling structure
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
# Saving to census_data/2011_Dwelling_structure.csv
# Year=2011 Table=Number of bedrooms
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
# Saving to census_data/2011_Number_of_bedrooms.csv
# Year=2011 Table=Tenure
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
# Saving to census_data/2011_Tenure.csv
# Year=2011 Table=Household composition
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
# Saving to census_data/2011_Household_composition.csv
# Year=2011 Table=Household income
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
# Saving to census_data/2011_Household_income.csv
# Year=2011 Table=Rent weekly payments
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
# Saving to census_data/2011_Rent_weekly_payments.csv
# Year=2011 Table=Mortgage monthly repayments
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
# Saving to census_data/2011_Mortgage_monthly_repayments.csv
# Year=2011 Table=Number of registered motor vehicles
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
# Saving to census_data/2011_Number_of_registered_motor_vehicles.csv
# Year=2011 Table=People characteristics
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
# Saving to census_data/2011_People_characteristics.csv
# Year=2011 Table=Dwelling characteristics
#     Iteration i=0
#     Iteration i=100
#     Iteration i=200
#     Iteration i=300
#     Iteration i=400
#     Iteration i=500
#     Iteration i=600
#     Iteration i=700
# Saving to census_data/2011_Dwelling_characteristics.csv
# Year=2016 Table=Age
# Year=2016 Table=Registered marital status
# Year=2016 Table=Social marital status
# Year=2016 Table=Education
# Year=2016 Table=Level of highest Educational attainment
# Year=2016 Table=Country of birth
# Year=2016 Table=Country of birth of father and/or mother
# Year=2016 Table=Employment
# Year=2016 Table=Employment - hours worked
# Year=2016 Table=Median weekly incomes
# Year=2016 Table=Unpaid work
# Year=2016 Table=Unpaid domestic work
# Year=2016 Table=Family composition
# Year=2016 Table=Single (or lone) parents
# Year=2016 Table=Employment status of parents in couple families
# Year=2016 Table=Dwelling type
# Year=2016 Table=Occupied private dwellings
# Year=2016 Table=Number of bedrooms
# Year=2016 Table=Tenure
# Year=2016 Table=Household composition
# Year=2016 Table=Household income
# Year=2016 Table=Rent weekly payments
# Year=2016 Table=Mortgage monthly repayments
# Year=2016 Table=Number of registered motor vehicles
# Year=2016 Table=Dwelling internet connection
# Year=2016 Table=People characteristics
# Year=2016 Table=Dwelling characteristics

# %%
errortables[15]
table = errortables[15]
table.find_all('tr')[1].find_all('td')[0]
values = []
for row in table.find_all('tr')[1:]:
    try:
        record = [row.find_all('td')[0].text]
        records = record + [convert(x.text) for x in row.find_all('td')[1:]]
        if len(records) == 1:
            continue
        values.append(records)
    except IndexError:
        print(record)
        print(row.find('td'))
# Out:
# ['Total families']
# None

# %%
# open pickle file
with open('source{}.pkl'.format(year), 'rb') as f:
    source = pickle.load(f)

# %%
with open('source2001.pkl', 'rb') as f:
    d = pickle.load(f)
    
# soup = d['Burwood']
soup = bs(d2016['Burwood'], 'html')
tables = soup.find_all('table')

parse_common_table(tables[16], '2016')
# Out:
# EmploymentPeople who reported being in the labour force, aged 15 years and over Worked full-time  \
# Burwood (NSW)                                                                               4289
# New South Wales                                                                      2.13452e+06
# Australia                                                                            6.62306e+06
#
# EmploymentPeople who reported being in the labour force, aged 15 years and over Worked part-time  \
# Burwood (NSW)                                                                               2536
# New South Wales                                                                      1.07115e+06
# Australia                                                                             3.4915e+06
#
# EmploymentPeople who reported being in the labour force, aged 15 years and over Away from work  \
# Burwood (NSW)                                                                              362
# New South Wales                                                                         174654
# Australia                                                                               569276
#
# EmploymentPeople who reported being in the labour force, aged 15 years and over Unemployed  \
# Burwood (NSW)                                                                          795
# New South Wales                                                                     225546
# Australia                                                                           787452
#
# EmploymentPeople who reported being in the labour force, aged 15 years and over Worked full-time (%)  \
# Burwood (NSW)                                                                                   53.7
# New South Wales                                                                                 59.2
# Australia                                                                                       57.7
#
# EmploymentPeople who reported being in the labour force, aged 15 years and over Worked part-time (%)  \
# Burwood (NSW)                                                                                   31.8
# New South Wales                                                                                 29.7
# Australia                                                                                       30.4
#
# EmploymentPeople who reported being in the labour force, aged 15 years and over Away from work (%)  \
# Burwood (NSW)                                                                                  4.5
# New South Wales                                                                                4.8
# Australia                                                                                      5.0
#
# EmploymentPeople who reported being in the labour force, aged 15 years and over Unemployed (%)
# Burwood (NSW)                                                                             10.0
# New South Wales                                                                            6.3
# Australia                                                                                  6.9

# %%
def convert(val):
    """Convert a value to numeric if it is."""
    val = val.replace(',', '')
    val = float(val) if val.isdigit() else val
    return val

def get_values_2006(table):
    """Parse table for 2006 html page."""
    # find values
    values = []
    for row in table.find_all('tr')[1:]:
        if row.find('td') is None:
            continue
        record = [row.find_all('td')[0].text]
        records = record + [convert(x.text) for x in row.find_all('td')[1:]]
        if len(records) == 1:
            continue
        values.append(records)
    return values

def get_values_2016(table):
    """Parse table for 2016 html page."""
    # find values
    values = []
    for row in table.find_all('tr')[1:]:
        if row.find('td') is None:
            continue
        record = [row.find_all('th')[0].text]
        records = record + [convert(x.text) for x in row.find_all('td')]
        values.append(records)
    return values

def parse_common_table(table, year):
    """Parse table that has common row names across different suburbs."""
    # find column names
    row = table.find_all('tr')[0]
    columns = [x.text for x in row.find_all('th')]
    for i, x in enumerate(columns):
        if x == '%':
            columns[i] = columns[i - 1] + " (%)"
    
    if year != '2016':
        values = get_values_2006(table)
    else:
        values = get_values_2016(table)
    
    data = pd.DataFrame(values, columns=columns).T
    data.columns = data.iloc[0]
    data = data.iloc[1:]

    # create double columns for percentage
    columns = list(data.columns)
    newcolumns = [x + ' (%)' for x in columns]
    for x in newcolumns:
        data[x] = None
        
    # find percentage rows and fill in value
    index = [x for x in data.index if '%' in x]
    for i in index:
        record = data.loc[i]
        rowname = ' '.join(i.split(' ')[:-1])
        for x in columns:
            data.at[rowname, x + ' (%)'] =  record[x]
    
    # drop those rows
    data = data.drop(index)
    return data

# %%
ages = tables[4]
# tables[4]

table = tables[4]

# find column names
row = table.find_all('tr')[0]
columns = [x.text for x in row.find_all('th')]
for i, x in enumerate(columns):
    if x == '%':
        columns[i] = columns[i - 1] + " (%)"
columns

values = get_values_2006(table)

values

data = pd.DataFrame(values, columns=columns).T
data.columns = data.iloc[0]
data = data.iloc[1:]

data
# Out:
# Median weekly incomes Personal Family Household Personal (%) Family (%)  \
# Burwood                    370   1115      1005           --         --
# Australia                  466   1171      1027           --         --
#
# Median weekly incomes Household (%)
# Burwood                          --
# Australia                        --

# %%
# Out:
# Iteration i=0
# Abbotsbury
# Iteration i=100
# Burwood
# Iteration i=200
# Dover Heights
# Index is out of tables length
# Iteration i=300
# Heathcote
# Index is out of tables length
# Index is out of tables length
# Iteration i=400
# Macquarie Park
# Index is out of tables length
# Index is out of tables length
# Iteration i=500
# Oatlands
# Index is out of tables length
# Iteration i=600
# Springfield
# Index is out of tables length
# Index is out of tables length
# Iteration i=700
# Whitebridge

# %%
suburb = 'Hillsborough'
print(suburb)
soup = bs(txt, 'html')
# find all tables
tables = soup.find_all('table')
# tables[0].find_all('td')[0].text
len(tables)
# sdata = parse_common_table(tables[index], '2016')
# Out:
# Hillsborough
# 3

# %%
# ...                                                                    ...
# Willoughby East                                                       63.2
# Windale                                                               27.2
# Windang                                                               44.6
# Winmalee                                                              55.8
# Winston Hills                                                         60.0
# Wollongong                                                            32.9
# Wollstonecraft                                                        41.9
# Wombarra                                                              50.5
# Woodbine (NSW)                                                        53.3
# Woodcroft (NSW)                                                       58.6
# Woodpark                                                              52.8
# Woodrising                                                            43.8
# Woollahra                                                             42.1
# Woolloomooloo                                                         21.2
# Woolooware                                                            50.4
# Woolwich                                                              56.7
# Woonona                                                               51.3
# Woronora                                                              55.9
# Woronora Heights                                                      60.6
# Woy Woy                                                               39.2
# Woy Woy Bay                                                           58.9
# Wyoming                                                               43.9
# Wyong                                                                 38.3
# Wyongah                                                               44.9
# Yagoona                                                               48.6
# Yarrawarrah                                                           63.6
# Yattalunga (NSW)                                                      59.4
# Yennora                                                               41.8
# Yowie Bay                                                             59.2
# Zetland                                                               25.0
#
# Social marital statusPeople aged 15 years and over De facto marriage (%)  \
# Abbotsbury                                                           4.0
# New South Wales                                                      9.4
# Australia                                                           10.4
# Abbotsford (NSW)                                                    10.0
# Acacia Gardens                                                       4.8
# Adamstown                                                           12.7
# Adamstown Heights                                                    6.9
# Airds                                                                9.8
# Albion Park                                                         10.0
# Albion Park Rail                                                    11.1
# Alexandria                                                          27.2
# Alfords Point                                                        3.6
# Allambie Heights                                                     6.7
# Allawah                                                              5.7
# Ambarvale                                                           10.0
# Annandale (NSW)                                                     18.2
# Argenton                                                            13.6
# Arncliffe                                                            9.2
# Artarmon                                                             9.4
# Ashbury                                                              5.6
# Ashcroft                                                             6.0
# Ashfield (NSW)                                                       9.9
# Asquith                                                              4.6
# Auburn (NSW)                                                         2.7
# Austinmer                                                           11.1
# Avoca Beach                                                          8.4
# Balgowlah                                                           12.2
# Balgowlah Heights                                                    5.1
# Balgownie                                                            7.0
# Balmain                                                             15.2
# ...                                                                  ...
# Willoughby East                                                      6.0
# Windale                                                             11.4
# Windang                                                              8.0
# Winmalee                                                             9.5
# Winston Hills                                                        5.4
# Wollongong                                                          11.1
# Wollstonecraft                                                      16.0
# Wombarra                                                            14.4
# Woodbine (NSW)                                                       8.4
# Woodcroft (NSW)                                                      3.9
# Woodpark                                                             6.8
# Woodrising                                                          10.8
# Woollahra                                                           14.5
# Woolloomooloo                                                       18.1
# Woolooware                                                           9.5
# Woolwich                                                             8.7
# Woonona                                                              8.7
# Woronora                                                             9.4
# Woronora Heights                                                     3.9
# Woy Woy                                                             10.4
# Woy Woy Bay                                                         12.6
# Wyoming                                                             10.5
# Wyong                                                                9.4
# Wyongah                                                             11.5
# Yagoona                                                              4.3
# Yarrawarrah                                                          5.6
# Yattalunga (NSW)                                                     9.8
# Yennora                                                              4.5
# Yowie Bay                                                            4.8
# Zetland                                                             21.1
#
# Social marital statusPeople aged 15 years and over Not married (%)
# Abbotsbury                                                    41.9
# New South Wales                                               42.3
# Australia                                                     41.9
# Abbotsford (NSW)                                              39.5
# Acacia Gardens                                                34.8
# Adamstown                                                     47.3
# Adamstown Heights                                             33.8
# Airds                                                         68.2
# Albion Park                                                   37.0
# Albion Park Rail                                              43.1
# Alexandria                                                    45.2
# Alfords Point                                                 36.0
# Allambie Heights                                              36.2
# Allawah                                                       45.8
# Ambarvale                                                     48.5
# Annandale (NSW)                                               43.5
# Argenton                                                      51.9
# Arncliffe                                                     48.1
# Artarmon                                                      40.8
# Ashbury                                                       38.6
# Ashcroft                                                      56.7
# Ashfield (NSW)                                                49.5
# Asquith                                                       36.9
# Auburn (NSW)                                                  51.7
# Austinmer                                                     36.1
# Avoca Beach                                                   35.7
# Balgowlah                                                     36.8
# Balgowlah Heights                                             31.0
# Balgownie                                                     39.4
# Balmain                                                       41.0
# ...                                                            ...
# Willoughby East                                               30.7
# Windale                                                       61.4
# Windang                                                       47.4
# Winmalee                                                      34.6
# Winston Hills                                                 34.6
# Wollongong                                                    56.1
# Wollstonecraft                                                42.1
# Wombarra                                                      35.0
# Woodbine (NSW)                                                38.3
# Woodcroft (NSW)                                               37.5
# Woodpark                                                      40.4
# Woodrising                                                    45.3
# Woollahra                                                     43.5
# Woolloomooloo                                                 60.7
# Woolooware                                                    40.2
# Woolwich                                                      34.6
# Woonona                                                       40.1
# Woronora                                                      34.7
# Woronora Heights                                              35.5
# Woy Woy                                                       50.4
# Woy Woy Bay                                                   28.5
# Wyoming                                                       45.6
# Wyong                                                         52.3
# Wyongah                                                       43.6
# Yagoona                                                       47.1
# Yarrawarrah                                                   30.8
# Yattalunga (NSW)                                              30.8
# Yennora                                                       53.7
# Yowie Bay                                                     36.0
# Zetland                                                       53.9
#
# [729 rows x 6 columns]

# %%
table = tables[9]
# find column names
row = table.find_all('tr')[0]
columns = [x.text for x in row.find_all('th')]
for i, x in enumerate(columns):
    if x == '%':
        columns[i] = columns[i - 1] + " (%)"
# find values
values = []
for row in table.find_all('tr')[1:]:
    record = [row.find_all('th')[0].text]
    records = record + [convert(x.text) for x in row.find_all('td')]
    values.append(records)

table
# Out:
# <table id="ancestryTable"><!-- Ancestry, top responses -->
# <tr>
# <th class="firstCol topRow" scope="col"><a class="dictionaryLink" href="/ausstats/abs@.nsf/Lookup/2901.0Chapter20802016" target="_blank" title="A person's ancestry, when used in conjunction with the person's country of birth and whether the person's parents were born in Australia or overseas, provides a good indication of the ethnic background of first and second generation Australians.">Ancestry, top responses</a></th>
# <th class="geoCol" scope="col">Burwood (NSW)</th>
# <th class="percentCol" scope="col">%</th>
# <th class="geoCol supressCol" scope="col">New South Wales</th>
# <th class="percentCol supressCol" scope="col">%</th>
# <th class="geoCol" scope="col">Australia</th>
# <th class="percentCol" scope="col">%</th>
# </tr>
# </table>

# %%
scripts = soup.find_all('script')
scripts[9].attrs
# Out:
# {'type': 'text/javascript'}

# %%
javascript = [x for x in scripts if 'src' not in x.attrs and 'type' in x.attrs
              and x.attrs['type'] == 'text/javascript'][0]

# javascript

# %%
re.compile("var ancestryData = \[\];").findall(javascript.text)
# Out:
# []

# %%
float(people.find_all('td')[1].text.replace(',', ''))
# Out:
# 21260.0
