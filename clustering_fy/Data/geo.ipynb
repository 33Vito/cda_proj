# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as pl

# %%
shape = gpd.read_file('source/ssc_2016_aust_shape/SSC_2016_AUST.shp')

# %%
shape.head()
# Out:
#   SSC_CODE16         SSC_NAME16 STE_CODE16       STE_NAME16  AREASQKM16  \
# 0      10001        Aarons Pass          1  New South Wales     82.7639
# 1      10002         Abbotsbury          1  New South Wales      4.9788
# 2      10003   Abbotsford (NSW)          1  New South Wales      1.0180
# 3      10004        Abercrombie          1  New South Wales      2.9775
# 4      10005  Abercrombie River          1  New South Wales    127.1701
#
#                                             geometry
# 0  POLYGON ((149.749955589 -32.86361148199995, 14...
# 1  POLYGON ((150.863346005 -33.86453699899994, 15...
# 2  POLYGON ((151.1242916220001 -33.84641125299993...
# 3  POLYGON ((149.547062017 -33.39074400599998, 14...
# 4  POLYGON ((149.274735006 -33.93369099699993, 14...

# %%
sscmap = pd.read_csv('SSC_final.csv')
sscmap.head()
# Out:
#        SSC_2006_NAME  SSC_CODE_2001  SSC_CODE_2006  SSC_CODE_2011  \
# 0         Abbotsbury          11006          11003          10001
# 1         Abbotsford          11011          11005          10002
# 2     Acacia Gardens          11016          11007          10010
# 3          Adamstown          16006          14006          10012
# 4  Adamstown Heights          16011          14011          10013
#
#    SSC_CODE_2016
# 0          10002
# 1          10003
# 2          10014
# 3          10016
# 4          10017

# %%
codename = sscmap.set_index('SSC_CODE_2016')['SSC_2006_NAME'].to_dict()

# %%
language = pd.read_csv('census_data/2016_Language_top_responses5.csv')
language.head()
# Out:
#         Unnamed: 0 Assyrian Neo-Aramaic  Italian   Arabic Vietnamese  Spanish  \
# 0       Abbotsbury                  296      278      193        147      141
# 1  New South Wales               20,317   75,694  200,825    102,896   63,527
# 2        Australia               28,349  271,597  321,728    277,400  140,817
# 3       Abbotsford                  NaN      486      NaN        NaN       84
# 4   Acacia Gardens                  NaN      NaN       65        NaN      NaN
#
#   English only spoken at home  \
# 0                       2,206
# 1                   5,126,633
# 2                  17,020,417
# 3                       3,549
# 4                       2,055
#
#   Households where a non English language is spoken Mandarin Cantonese  ...  \
# 0                                               706      NaN       NaN  ...
# 1                                           735,563      NaN       NaN  ...
# 2                                         1,971,011      NaN       NaN  ...
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-3d22ebcb15fc> in <module>
# ----> 1 language.columns[0] = 'Suburb'
#
# ~/.virtualenvs/census/lib/python3.6/site-packages/pandas/core/indexes/base.py in __setitem__(self, key, value)
#    3936
#    3937     def __setitem__(self, key, value):
# -> 3938         raise TypeError("Index does not support mutable operations")
#    3939
#    3940     def __getitem__(self, key):
#
# TypeError: Index does not support mutable operations
